# %% [markdown]
# #Imports and Configurations

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd drive/MyDrive/Audio_Final_Project/Siamese_Network
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [Errno 2] No such file or directory: 'drive/MyDrive/Audio_Final_Project/Siamese_Network'
# /content/drive/MyDrive/Audio_Final_Project/Siamese_Network

# %%
import pickle
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, BatchNormalization,\
    Dropout, Activation, Lambda, concatenate
from tensorflow.keras.models import Model, Sequential

# %% [markdown]
# #Siamese Architecture

# %%
def build_conv_branch(name, input_shape):
        model = Sequential(name=name)
        # Layer 1
        model.add(Conv2D(64, (3, 3), padding='same', kernel_initializer='he_uniform', input_shape=input_shape))
        model.add(BatchNormalization())
        model.add(Activation('relu'))
        model.add(MaxPooling2D(pool_size=(2, 2)))
        # Layer 2
        model.add(Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform'))
        model.add(BatchNormalization())
        model.add(Activation('relu'))
        model.add(MaxPooling2D(pool_size=(2, 2)))
        # Layer 3
        model.add(Conv2D(128, (3, 3), padding='same', kernel_initializer='he_uniform'))
        model.add(BatchNormalization())
        model.add(Activation('relu'))
        model.add(MaxPooling2D(pool_size=(2, 2)))

        return model

def flatten_conv(x, dropout_rate):
    x = Flatten()(x)
    x = Dense(256, kernel_initializer='he_uniform')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(dropout_rate)(x)

    x = Dense(256, kernel_initializer='he_uniform')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(dropout_rate)(x)

    x = Dense(128, kernel_initializer='he_uniform')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(dropout_rate)(x)

    return x

def siamese_network(input_shape, loss_method, dropout_rate=0.2):
    if loss_method == 'triplet':
        input_anchor = Input(input_shape)
        input_positive = Input(input_shape)
        input_negative = Input(input_shape)

        model_inputs = [input_anchor, input_positive, input_negative]

        processed_anchor = build_conv_branch(name="triplet_branch", input_shape=input_shape)
        processed_positive = build_conv_branch(name="", input_shape=input_shape)
        processed_negative = build_conv_branch(name="", input_shape=input_shape)

        output_anchor = flatten_conv(processed_anchor(input_anchor), dropout_rate=dropout_rate)
        output_positive = flatten_conv(processed_positive(input_positive), dropout_rate=dropout_rate)
        output_negative = flatten_conv(processed_negative(input_negative), dropout_rate=dropout_rate)

        model_output = concatenate([output_anchor, output_positive, output_negative])

    else:
        input_a = Input(shape=input_shape)
        input_b = Input(shape=input_shape)
        model_inputs = [input_a, input_b]

        processed_a = build_conv_branch(name="contrast_branch", input_shape=input_shape)
        processed_b = build_conv_branch(name="", input_shape=input_shape)

        output_a = flatten_conv(processed_a(input_a), dropout_rate=dropout_rate)
        output_b = flatten_conv(processed_b(input_b), dropout_rate=dropout_rate)

        model_output = Lambda(lambda embeddings: K.abs(embeddings[0] - embeddings[1]))([output_a, output_b])

    model = Model(inputs=model_inputs, outputs=model_output)

    return model

# %% [markdown]
# #Loss Metrics

# %%
@tf.function
def contrastive_loss(y_true, y_pred, margin=1):
    square_pred = tf.square(y_pred)
    margin_square = tf.square(tf.maximum(margin - y_pred, 0))
    return tf.reduce_mean(y_true * square_pred + (1 - y_true) * margin_square)

@tf.function
def triplet_loss(y_true, y_pred, alpha=0.001):
    length = y_pred.shape[1]
    divided_size = int(length / 3)

    anchor = y_pred[:, :divided_size]
    positive = y_pred[:, divided_size:divided_size * 2]
    negative = y_pred[:, divided_size * 2:]
    pos_dist = tf.reduce_sum(tf.square(anchor - positive), axis=1)
    neg_dist = tf.reduce_sum(tf.square(anchor - negative), axis=1)

    basic_loss = pos_dist - neg_dist + alpha
    loss = tf.maximum(basic_loss, 0.0)

    return loss

# %% [markdown]
# #Models Fit Function

# %%
def fit_and_save_model(datasets, input_shape, batch_size, loss_method, epochs, dtype):
    assert dtype in ['30_sec', '3_sec'], "dtype must be '30_sec' or '3_sec'"

    loss_metric = triplet_loss if loss_method == 'triplet' else contrastive_loss
    X_train, X_test, y_train, y_test = datasets
    model = siamese_network(input_shape, loss_method)
    print("Model is created, starting train process ...")
    opt = tf.compat.v1.train.AdamOptimizer(learning_rate=0.00001)
    model.compile(optimizer=opt, loss=loss_metric)
    early_stopping = EarlyStopping(monitor='val_loss', patience=20, verbose=1, mode='min', restore_best_weights=True)
    history = model.fit(X_train, y_train,
                        validation_data=(X_test, y_test),
                        batch_size=batch_size, epochs=epochs, verbose=1,
                        callbacks=[early_stopping])

    anchor_branch_layer = model.get_layer(f'{loss_method}_branch')
    weights_path = f'{dtype}/{loss_method}_branch.h5'
    anchor_branch_layer.save_weights(weights_path)

    pickle.dump(history.history, open(f'{dtype}/{loss_method}_history.pkl', 'wb'))

    return model

# %% [markdown]
# #Data Preprocessing

# %%
def load_dataset(loss_method, dataset_paths, is_train_process=True):
    if loss_method == 'triplet':
        if is_train_process:
            train_anchors = np.load(dataset_paths['train_anchors'])
            train_positives = np.load(dataset_paths['train_positives'])
            train_negatives = np.load(dataset_paths['train_negatives'])

            val_anchors = np.load(dataset_paths['val_anchors'])
            val_positives = np.load(dataset_paths['val_positives'])
            val_negatives = np.load(dataset_paths['val_negatives'])

            input_shape = train_anchors.shape[1:]
            y_train = np.zeros((train_anchors.shape[0],))
            y_val = np.zeros((val_anchors.shape[0],))

            X_train = [train_anchors, train_positives, train_negatives]
            X_val = [val_anchors, val_positives, val_negatives]

        else:
            val_anchors = np.load(dataset_paths['test_anchors'])
            val_positives = np.load(dataset_paths['test_positives'])
            val_negatives = np.load(dataset_paths['test_negatives'])

            input_shape = val_anchors.shape[1:]
            y_val = np.zeros((val_anchors.shape[0],))
            X_val = [val_anchors, val_positives, val_negatives]
            X_train, y_train = [], []

    else:
        if is_train_process:
            X_train = np.load(dataset_paths['X_train'])
            y_train = np.load(dataset_paths['y_train'])
            X_val = np.load(dataset_paths['X_val'])
            y_val = np.load(dataset_paths['y_val'])

            input_shape = X_train.shape[2:]
            X_train = [X_train[:, 0], X_train[:, 1]]
            X_val = [X_val[:, 0], X_val[:, 1]]

        else:
            X_val = np.load(dataset_paths['X_test'])
            y_val = np.load(dataset_paths['y_test'])

            input_shape = X_val.shape[2:]
            X_val = [X_val[:, 0], X_val[:, 1]]
            X_train, y_train = [], []

    return X_train, X_val, y_train, y_val, input_shape

# %% [markdown]
# #30 Seconds Files

# %%
triplets_path = '../datasets/30_sec_datasets/triplets_dataset'
dataset_paths_triplet = {f"{dataset}_{type}": f"{triplets_path}/{type}_{dataset}.npy"
                            for dataset in ['train', 'val', 'test'] for type in ['anchors', 'positives', 'negatives']}

pairs_path = '../datasets/30_sec_datasets/pairs_dataset/'
dataset_paths_pairs = {f"{d_type}_{dataset}": f"{pairs_path}{d_type}_{dataset}_pairs.npy" for dataset in ['train', 'val', 'test'] for d_type in ['X', 'y']}

# %% [markdown]
# ##Triplet Loss Model

# %%
X_train, X_test, y_train, y_test, input_shape = load_dataset('triplet', dataset_paths_triplet, is_train_process=True)
datasets = [X_train, X_test, y_train, y_test]
print("Datasets are loaded")
# Out:
# Datasets are loaded

# %%
train_indices = np.arange(X_train[0].shape[0])
np.random.shuffle(train_indices)
X_train_shuffled = [X_train[i][train_indices] for i in range(len(X_train))]
y_train_shuffled = y_train[train_indices]

validation_indices = np.arange(X_test[0].shape[0])
np.random.shuffle(validation_indices)
X_validation_shuffled = [X_test[i][validation_indices] for i in range(len(X_test))]
y_validation_shuffled = y_test[validation_indices]
datasets = [X_train_shuffled, X_validation_shuffled, y_train_shuffled, y_validation_shuffled]

# %%
triplet_model = fit_and_save_model(datasets, input_shape, batch_size=4, loss_method='triplet', epochs=100, dtype='30_sec')
# Out:
# Model is created, starting train process ...
# Epoch 1/100
# 160/160 [==============================] - 10s 39ms/step - loss: 6.7580 - val_loss: 10.6486
# Epoch 2/100
# 160/160 [==============================] - 4s 25ms/step - loss: 6.1251 - val_loss: 5.7705
# Epoch 3/100
# 160/160 [==============================] - 4s 24ms/step - loss: 5.7641 - val_loss: 6.9991
# Epoch 4/100
# 160/160 [==============================] - 4s 24ms/step - loss: 5.3646 - val_loss: 12.7356
# Epoch 5/100
# 160/160 [==============================] - 4s 25ms/step - loss: 5.4552 - val_loss: 11.2671
# Epoch 6/100
# 160/160 [==============================] - 4s 24ms/step - loss: 5.8305 - val_loss: 11.6642
# Epoch 7/100
# 160/160 [==============================] - 4s 24ms/step - loss: 4.7586 - val_loss: 12.3976
# Epoch 8/100
# 160/160 [==============================] - 4s 24ms/step - loss: 4.7949 - val_loss: 7.4191
# Epoch 9/100
# 160/160 [==============================] - 4s 25ms/step - loss: 3.7586 - val_loss: 5.4486
# Epoch 10/100
# 160/160 [==============================] - 4s 25ms/step - loss: 4.2817 - val_loss: 7.9783
# Epoch 11/100
# 160/160 [==============================] - 4s 24ms/step - loss: 4.0451 - val_loss: 7.6704
# Epoch 12/100
# 160/160 [==============================] - 4s 24ms/step - loss: 3.9036 - val_loss: 7.3293
# Epoch 13/100
# 160/160 [==============================] - 4s 24ms/step - loss: 3.7061 - val_loss: 10.0935
# Epoch 14/100
# 160/160 [==============================] - 4s 25ms/step - loss: 3.6989 - val_loss: 11.0170
# Epoch 15/100
# 160/160 [==============================] - 4s 25ms/step - loss: 3.6462 - val_loss: 7.1122
# Epoch 16/100
# 160/160 [==============================] - 4s 24ms/step - loss: 3.5855 - val_loss: 8.8512
# Epoch 17/100
# 160/160 [==============================] - 4s 24ms/step - loss: 3.7953 - val_loss: 8.4455
# Epoch 18/100
# 160/160 [==============================] - 4s 24ms/step - loss: 3.7046 - val_loss: 6.7812
# Epoch 19/100
# 160/160 [==============================] - 4s 25ms/step - loss: 3.5357 - val_loss: 6.8270
# Epoch 20/100
# 160/160 [==============================] - 4s 26ms/step - loss: 3.0134 - val_loss: 5.4056
# Epoch 21/100
# 160/160 [==============================] - 4s 24ms/step - loss: 2.8048 - val_loss: 7.4781
# Epoch 22/100
# 160/160 [==============================] - 4s 24ms/step - loss: 2.7743 - val_loss: 6.2614
# Epoch 23/100
# 160/160 [==============================] - 4s 24ms/step - loss: 2.9616 - val_loss: 6.7276
# Epoch 24/100
# 160/160 [==============================] - 4s 26ms/step - loss: 3.0456 - val_loss: 4.4381
# Epoch 25/100
# 160/160 [==============================] - 4s 24ms/step - loss: 2.7727 - val_loss: 5.6603
# Epoch 26/100
# 160/160 [==============================] - 4s 25ms/step - loss: 2.6274 - val_loss: 3.6243
# Epoch 27/100
# 160/160 [==============================] - 4s 24ms/step - loss: 2.1122 - val_loss: 4.6980
# Epoch 28/100
# 160/160 [==============================] - 4s 24ms/step - loss: 2.0782 - val_loss: 7.0127
# Epoch 29/100
# 160/160 [==============================] - 4s 25ms/step - loss: 2.0687 - val_loss: 4.8281
# Epoch 30/100
# 160/160 [==============================] - 4s 24ms/step - loss: 2.1825 - val_loss: 4.2054
# Epoch 31/100
# 160/160 [==============================] - 4s 24ms/step - loss: 2.0825 - val_loss: 4.3055
# Epoch 32/100
# 160/160 [==============================] - 4s 24ms/step - loss: 2.3293 - val_loss: 5.0368
# Epoch 33/100
# 160/160 [==============================] - 4s 24ms/step - loss: 2.3791 - val_loss: 4.7732
# Epoch 34/100
# 160/160 [==============================] - 4s 25ms/step - loss: 2.2096 - val_loss: 5.8374
# Epoch 35/100
# 160/160 [==============================] - 4s 24ms/step - loss: 2.5680 - val_loss: 7.3610
# Epoch 36/100
# 160/160 [==============================] - 4s 24ms/step - loss: 2.0678 - val_loss: 5.0976
# Epoch 37/100
# 160/160 [==============================] - 4s 24ms/step - loss: 1.7321 - val_loss: 4.4035
# Epoch 38/100
# 160/160 [==============================] - 4s 26ms/step - loss: 2.0318 - val_loss: 3.5693
# Epoch 39/100
# 160/160 [==============================] - 4s 26ms/step - loss: 1.9140 - val_loss: 3.3336
# Epoch 40/100
# 160/160 [==============================] - 4s 24ms/step - loss: 2.1078 - val_loss: 3.7902
# Epoch 41/100
# 160/160 [==============================] - 4s 24ms/step - loss: 1.6560 - val_loss: 4.7167
# Epoch 42/100
# 160/160 [==============================] - 4s 24ms/step - loss: 1.6462 - val_loss: 6.4074
# Epoch 43/100
# 160/160 [==============================] - 4s 25ms/step - loss: 1.5179 - val_loss: 4.4665
# Epoch 44/100
# 160/160 [==============================] - 4s 25ms/step - loss: 1.2866 - val_loss: 4.4695
# Epoch 45/100
# 160/160 [==============================] - 4s 24ms/step - loss: 1.3811 - val_loss: 6.3183
# Epoch 46/100
# 160/160 [==============================] - 4s 24ms/step - loss: 1.3444 - val_loss: 6.2070
# Epoch 47/100
# 160/160 [==============================] - 4s 24ms/step - loss: 1.4034 - val_loss: 5.2342
# Epoch 48/100
# 160/160 [==============================] - 4s 25ms/step - loss: 1.3983 - val_loss: 4.3713
# Epoch 49/100
# 160/160 [==============================] - 4s 24ms/step - loss: 1.7221 - val_loss: 5.1821
# Epoch 50/100
# 160/160 [==============================] - 4s 24ms/step - loss: 1.4085 - val_loss: 3.7449
# Epoch 51/100
# 160/160 [==============================] - 4s 25ms/step - loss: 1.4886 - val_loss: 3.1398
# Epoch 52/100
# 160/160 [==============================] - 4s 26ms/step - loss: 1.1958 - val_loss: 2.9178
# Epoch 53/100
# 160/160 [==============================] - 4s 25ms/step - loss: 1.7537 - val_loss: 3.6057
# Epoch 54/100
# 160/160 [==============================] - 4s 24ms/step - loss: 0.9732 - val_loss: 4.3250
# Epoch 55/100
# 160/160 [==============================] - 4s 24ms/step - loss: 0.9205 - val_loss: 4.5333
# Epoch 56/100
# 160/160 [==============================] - 4s 24ms/step - loss: 1.1080 - val_loss: 3.9084
# Epoch 57/100
# 160/160 [==============================] - 4s 25ms/step - loss: 1.3361 - val_loss: 4.1029
# Epoch 58/100
# 160/160 [==============================] - 4s 25ms/step - loss: 1.3144 - val_loss: 3.8547
# Epoch 59/100
# 160/160 [==============================] - 4s 24ms/step - loss: 1.0333 - val_loss: 4.3054
# Epoch 60/100
# 160/160 [==============================] - 4s 24ms/step - loss: 0.9853 - val_loss: 4.9679
# Epoch 61/100
# 160/160 [==============================] - 4s 24ms/step - loss: 1.1091 - val_loss: 2.9970
# Epoch 62/100
# 160/160 [==============================] - 4s 25ms/step - loss: 1.0883 - val_loss: 3.1192
# Epoch 63/100
# 160/160 [==============================] - 4s 24ms/step - loss: 1.1353 - val_loss: 3.1080
# Epoch 64/100
# 160/160 [==============================] - 4s 24ms/step - loss: 0.9739 - val_loss: 4.4272
# Epoch 65/100
# 160/160 [==============================] - 4s 24ms/step - loss: 1.0794 - val_loss: 4.1654
# Epoch 66/100
# 160/160 [==============================] - 4s 24ms/step - loss: 0.8850 - val_loss: 3.7085
# Epoch 67/100
# 160/160 [==============================] - 4s 26ms/step - loss: 1.2529 - val_loss: 2.8305
# Epoch 68/100
# 160/160 [==============================] - 4s 24ms/step - loss: 1.1624 - val_loss: 3.5281
# Epoch 69/100
# 160/160 [==============================] - 4s 24ms/step - loss: 1.0125 - val_loss: 3.8861
# Epoch 70/100
# 160/160 [==============================] - 4s 24ms/step - loss: 0.9295 - val_loss: 3.5506
# Epoch 71/100
# 160/160 [==============================] - 4s 26ms/step - loss: 0.8787 - val_loss: 1.9533
# Epoch 72/100
# 160/160 [==============================] - 4s 25ms/step - loss: 0.9762 - val_loss: 2.6373
# Epoch 73/100
# 160/160 [==============================] - 4s 24ms/step - loss: 0.9192 - val_loss: 3.1273
# Epoch 74/100
# 160/160 [==============================] - 4s 24ms/step - loss: 0.9382 - val_loss: 3.0508
# Epoch 75/100
# 160/160 [==============================] - 4s 24ms/step - loss: 0.9611 - val_loss: 3.6153
# Epoch 76/100
# 160/160 [==============================] - 4s 25ms/step - loss: 0.6381 - val_loss: 2.2743
# Epoch 77/100
# 160/160 [==============================] - 4s 26ms/step - loss: 0.7029 - val_loss: 1.4890
# Epoch 78/100
# 160/160 [==============================] - 4s 25ms/step - loss: 1.2104 - val_loss: 1.4020
# Epoch 79/100
# 160/160 [==============================] - 4s 24ms/step - loss: 0.6717 - val_loss: 1.4881
# Epoch 80/100
# 160/160 [==============================] - 4s 24ms/step - loss: 0.6949 - val_loss: 2.6777
# Epoch 81/100
# 160/160 [==============================] - 4s 25ms/step - loss: 0.7419 - val_loss: 1.7619
# Epoch 82/100
# 160/160 [==============================] - 4s 24ms/step - loss: 0.7518 - val_loss: 2.4316
# Epoch 83/100
# 160/160 [==============================] - 4s 24ms/step - loss: 0.8376 - val_loss: 3.4369
# Epoch 84/100
# 160/160 [==============================] - 4s 24ms/step - loss: 0.7644 - val_loss: 5.4506
# Epoch 85/100
# 160/160 [==============================] - 4s 24ms/step - loss: 0.7758 - val_loss: 4.4177
# Epoch 86/100
# 160/160 [==============================] - 4s 25ms/step - loss: 0.4333 - val_loss: 4.3577
# Epoch 87/100
# 160/160 [==============================] - 4s 24ms/step - loss: 0.7720 - val_loss: 6.5937
# Epoch 88/100
# 160/160 [==============================] - 4s 24ms/step - loss: 0.5666 - val_loss: 5.7109
# Epoch 89/100
# 160/160 [==============================] - 4s 24ms/step - loss: 0.6705 - val_loss: 8.1943
# Epoch 90/100
# 160/160 [==============================] - 4s 25ms/step - loss: 0.8974 - val_loss: 5.3348
# Epoch 91/100
# 160/160 [==============================] - 4s 25ms/step - loss: 0.7987 - val_loss: 4.5487
# Epoch 92/100
# 160/160 [==============================] - 4s 24ms/step - loss: 0.7836 - val_loss: 5.4856
# Epoch 93/100
# 160/160 [==============================] - 4s 24ms/step - loss: 0.8403 - val_loss: 4.4457
# Epoch 94/100
# 160/160 [==============================] - 4s 24ms/step - loss: 0.6481 - val_loss: 5.7654
# Epoch 95/100
# 160/160 [==============================] - 4s 25ms/step - loss: 0.5648 - val_loss: 3.9945
# Epoch 96/100
# 160/160 [==============================] - 4s 25ms/step - loss: 0.7849 - val_loss: 6.7075
# Epoch 97/100
# 160/160 [==============================] - 4s 24ms/step - loss: 0.6311 - val_loss: 10.0398
# Epoch 98/100
# 160/160 [==============================] - ETA: 0s - loss: 0.6896Restoring model weights from the end of the best epoch: 78.
# 160/160 [==============================] - 4s 26ms/step - loss: 0.6896 - val_loss: 6.5417
# Epoch 98: early stopping

# %%
triplet_model = fit_and_save_model(datasets, input_shape, batch_size=64, loss_method='triplet', epochs=100, dtype='30_sec')
# Out:
# Model is created, starting train process ...
# Epoch 1/100
# 10/10 [==============================] - 31s 2s/step - loss: 13.8550 - val_loss: 98.7413
# Epoch 2/100
# 10/10 [==============================] - 2s 253ms/step - loss: 10.7663 - val_loss: 49.5877
# Epoch 3/100
# 10/10 [==============================] - 2s 250ms/step - loss: 8.3167 - val_loss: 29.0584
# Epoch 4/100
# 10/10 [==============================] - 2s 252ms/step - loss: 6.3955 - val_loss: 16.6670
# Epoch 5/100
# 10/10 [==============================] - 2s 250ms/step - loss: 5.1723 - val_loss: 8.6792
# Epoch 6/100
# 10/10 [==============================] - 2s 249ms/step - loss: 4.1205 - val_loss: 4.4527
# Epoch 7/100
# 10/10 [==============================] - 2s 252ms/step - loss: 4.1046 - val_loss: 1.2523
# Epoch 8/100
# 10/10 [==============================] - 2s 252ms/step - loss: 4.0872 - val_loss: 0.2791
# Epoch 9/100
# 10/10 [==============================] - 2s 228ms/step - loss: 2.7263 - val_loss: 0.3428
# Epoch 10/100
# 10/10 [==============================] - 2s 226ms/step - loss: 2.6854 - val_loss: 0.3841
# Epoch 11/100
# 10/10 [==============================] - 2s 228ms/step - loss: 2.3297 - val_loss: 0.3110
# Epoch 12/100
# 10/10 [==============================] - 2s 253ms/step - loss: 2.2219 - val_loss: 0.2120
# Epoch 13/100
# 10/10 [==============================] - 2s 228ms/step - loss: 2.2679 - val_loss: 0.2588
# Epoch 14/100
# 10/10 [==============================] - 2s 227ms/step - loss: 2.2351 - val_loss: 0.3770
# Epoch 15/100
# 10/10 [==============================] - 2s 226ms/step - loss: 2.0395 - val_loss: 0.2536
# Epoch 16/100
# 10/10 [==============================] - 2s 252ms/step - loss: 1.4848 - val_loss: 0.1022
# Epoch 17/100
# 10/10 [==============================] - 2s 251ms/step - loss: 1.9482 - val_loss: 0.0415
# Epoch 18/100
# 10/10 [==============================] - 2s 227ms/step - loss: 1.2881 - val_loss: 0.0744
# Epoch 19/100
# 10/10 [==============================] - 2s 227ms/step - loss: 1.3739 - val_loss: 0.0968
# Epoch 20/100
# 10/10 [==============================] - 2s 228ms/step - loss: 1.6517 - val_loss: 0.1183
# Epoch 21/100
# 10/10 [==============================] - 2s 226ms/step - loss: 1.1597 - val_loss: 0.1730
# Epoch 22/100
# 10/10 [==============================] - ETA: 0s - loss: 1.1703Restoring model weights from the end of the best epoch: 17.
# 10/10 [==============================] - 3s 261ms/step - loss: 1.1703 - val_loss: 0.2043
# Epoch 22: early stopping

# %%
_, X_test, _, y_test, input_shape = load_dataset('triplet', dataset_paths_triplet, is_train_process=False)
predictions = triplet_model.predict(X_test)

# %% [markdown]
# ##Contrastive Loss Model

# %%
X_train, X_test, y_train, y_test, input_shape = load_dataset('contrast', dataset_paths_pairs, is_train_process=True)
datasets = [X_train, X_test, y_train, y_test]
print("Datasets are loaded", input_shape)
# Out:
# Datasets are loaded (231, 232, 3)

# %%
contrast_model = fit_and_save_model(datasets, input_shape, batch_size=32, loss_method='contrast', epochs=100, dtype='30_sec')
# Out:
# Model is created, starting train process ...
# Epoch 1/100
# 20/20 [==============================] - 5s 137ms/step - loss: 0.8739 - val_loss: 0.9140
# Epoch 2/100
# 20/20 [==============================] - 2s 86ms/step - loss: 0.8128 - val_loss: 0.2895
# Epoch 3/100
# 20/20 [==============================] - 2s 87ms/step - loss: 0.7529 - val_loss: 0.1757
# Epoch 4/100
# 20/20 [==============================] - 2s 80ms/step - loss: 0.7121 - val_loss: 0.1973
# Epoch 5/100
# 20/20 [==============================] - 2s 81ms/step - loss: 0.6749 - val_loss: 0.1903
# Epoch 6/100
# 20/20 [==============================] - 2s 80ms/step - loss: 0.6449 - val_loss: 0.2116
# Epoch 7/100
# 20/20 [==============================] - 2s 81ms/step - loss: 0.6030 - val_loss: 0.1878
# Epoch 8/100
# 20/20 [==============================] - 2s 81ms/step - loss: 0.5767 - val_loss: 0.1784
# Epoch 9/100
# 20/20 [==============================] - 2s 87ms/step - loss: 0.5440 - val_loss: 0.1751
# Epoch 10/100
# 20/20 [==============================] - 2s 87ms/step - loss: 0.5117 - val_loss: 0.1645
# Epoch 11/100
# 20/20 [==============================] - 2s 79ms/step - loss: 0.4850 - val_loss: 0.1663
# Epoch 12/100
# 20/20 [==============================] - 2s 79ms/step - loss: 0.4519 - val_loss: 0.1662
# Epoch 13/100
# 20/20 [==============================] - 2s 88ms/step - loss: 0.4247 - val_loss: 0.1635
# Epoch 14/100
# 20/20 [==============================] - 2s 87ms/step - loss: 0.4021 - val_loss: 0.1626
# Epoch 15/100
# 20/20 [==============================] - 2s 79ms/step - loss: 0.3878 - val_loss: 0.1640
# Epoch 16/100
# 20/20 [==============================] - 2s 88ms/step - loss: 0.3581 - val_loss: 0.1478
# Epoch 17/100
# 20/20 [==============================] - 2s 87ms/step - loss: 0.3476 - val_loss: 0.1418
# Epoch 18/100
# 20/20 [==============================] - 2s 88ms/step - loss: 0.3242 - val_loss: 0.1405
# Epoch 19/100
# 20/20 [==============================] - 2s 88ms/step - loss: 0.3055 - val_loss: 0.1388
# Epoch 20/100
# 20/20 [==============================] - 2s 88ms/step - loss: 0.2904 - val_loss: 0.1305
# Epoch 21/100
# 20/20 [==============================] - 2s 88ms/step - loss: 0.2750 - val_loss: 0.1298
# Epoch 22/100
# 20/20 [==============================] - 2s 86ms/step - loss: 0.2684 - val_loss: 0.1215
# Epoch 23/100
# 20/20 [==============================] - 2s 87ms/step - loss: 0.2559 - val_loss: 0.1141
# Epoch 24/100
# 20/20 [==============================] - 2s 86ms/step - loss: 0.2420 - val_loss: 0.1071
# Epoch 25/100
# 20/20 [==============================] - 2s 86ms/step - loss: 0.2229 - val_loss: 0.1016
# Epoch 26/100
# 20/20 [==============================] - 2s 87ms/step - loss: 0.2186 - val_loss: 0.1009
# Epoch 27/100
# 20/20 [==============================] - 2s 87ms/step - loss: 0.2018 - val_loss: 0.0937
# Epoch 28/100
# 20/20 [==============================] - 2s 82ms/step - loss: 0.1971 - val_loss: 0.0954
# Epoch 29/100
# 20/20 [==============================] - 2s 88ms/step - loss: 0.1963 - val_loss: 0.0899
# Epoch 30/100
# 20/20 [==============================] - 2s 87ms/step - loss: 0.1812 - val_loss: 0.0851
# Epoch 31/100
# 20/20 [==============================] - 2s 87ms/step - loss: 0.1704 - val_loss: 0.0819
# Epoch 32/100
# 20/20 [==============================] - 2s 86ms/step - loss: 0.1648 - val_loss: 0.0802
# Epoch 33/100
# 20/20 [==============================] - 2s 87ms/step - loss: 0.1572 - val_loss: 0.0790
# Epoch 34/100
# 20/20 [==============================] - 2s 87ms/step - loss: 0.1571 - val_loss: 0.0770
# Epoch 35/100
# 20/20 [==============================] - 2s 88ms/step - loss: 0.1527 - val_loss: 0.0761
# Epoch 36/100
# 20/20 [==============================] - 2s 86ms/step - loss: 0.1462 - val_loss: 0.0728
# Epoch 37/100
# 20/20 [==============================] - 2s 80ms/step - loss: 0.1446 - val_loss: 0.0851
# Epoch 38/100
# 20/20 [==============================] - 2s 86ms/step - loss: 0.1364 - val_loss: 0.0723
# Epoch 39/100
# 20/20 [==============================] - 2s 87ms/step - loss: 0.1362 - val_loss: 0.0669
# Epoch 40/100
# 20/20 [==============================] - 2s 89ms/step - loss: 0.1337 - val_loss: 0.0647
# Epoch 41/100
# 20/20 [==============================] - 2s 88ms/step - loss: 0.1260 - val_loss: 0.0629
# Epoch 42/100
# 20/20 [==============================] - 2s 80ms/step - loss: 0.1269 - val_loss: 0.0690
# Epoch 43/100
# 20/20 [==============================] - 2s 87ms/step - loss: 0.1198 - val_loss: 0.0611
# Epoch 44/100
# 20/20 [==============================] - 2s 80ms/step - loss: 0.1179 - val_loss: 0.0617
# Epoch 45/100
# 20/20 [==============================] - 2s 86ms/step - loss: 0.1161 - val_loss: 0.0593
# Epoch 46/100
# 20/20 [==============================] - 2s 79ms/step - loss: 0.1266 - val_loss: 0.0715
# Epoch 47/100
# 20/20 [==============================] - 2s 80ms/step - loss: 0.1364 - val_loss: 0.0728
# Epoch 48/100
# 20/20 [==============================] - 2s 80ms/step - loss: 0.1214 - val_loss: 0.0635
# Epoch 49/100
# 20/20 [==============================] - 2s 88ms/step - loss: 0.1116 - val_loss: 0.0588
# Epoch 50/100
# 20/20 [==============================] - 2s 87ms/step - loss: 0.1031 - val_loss: 0.0577
# Epoch 51/100
# 20/20 [==============================] - 2s 80ms/step - loss: 0.1200 - val_loss: 0.0700
# Epoch 52/100
# 20/20 [==============================] - 2s 80ms/step - loss: 0.1100 - val_loss: 0.0647
# Epoch 53/100
# 20/20 [==============================] - 2s 80ms/step - loss: 0.1087 - val_loss: 0.0604
# Epoch 54/100
# 20/20 [==============================] - 2s 80ms/step - loss: 0.1051 - val_loss: 0.0579
# Epoch 55/100
# 20/20 [==============================] - 2s 79ms/step - loss: 0.0991 - val_loss: 0.0583
# Epoch 56/100
# 20/20 [==============================] - 2s 87ms/step - loss: 0.0986 - val_loss: 0.0567
# Epoch 57/100
# 20/20 [==============================] - 2s 87ms/step - loss: 0.0994 - val_loss: 0.0562
# Epoch 58/100
# 20/20 [==============================] - 2s 86ms/step - loss: 0.0953 - val_loss: 0.0552
# Epoch 59/100
# 20/20 [==============================] - 2s 79ms/step - loss: 0.0954 - val_loss: 0.0557
# Epoch 60/100
# 20/20 [==============================] - 2s 80ms/step - loss: 0.0979 - val_loss: 0.0569
# Epoch 61/100
# 20/20 [==============================] - 2s 79ms/step - loss: 0.0955 - val_loss: 0.0564
# Epoch 62/100
# 20/20 [==============================] - 2s 87ms/step - loss: 0.0937 - val_loss: 0.0538
# Epoch 63/100
# 20/20 [==============================] - 2s 81ms/step - loss: 0.0986 - val_loss: 0.0583
# Epoch 64/100
# 20/20 [==============================] - 2s 81ms/step - loss: 0.0949 - val_loss: 0.0581
# Epoch 65/100
# 20/20 [==============================] - 2s 80ms/step - loss: 0.0982 - val_loss: 0.0655
# Epoch 66/100
# 20/20 [==============================] - 2s 79ms/step - loss: 0.1052 - val_loss: 0.0672
# Epoch 67/100
# 20/20 [==============================] - 2s 79ms/step - loss: 0.1000 - val_loss: 0.0622
# Epoch 68/100
# 20/20 [==============================] - 2s 80ms/step - loss: 0.0948 - val_loss: 0.0568
# Epoch 69/100
# 20/20 [==============================] - 2s 80ms/step - loss: 0.0920 - val_loss: 0.0558
# Epoch 70/100
# 20/20 [==============================] - 2s 79ms/step - loss: 0.0926 - val_loss: 0.0553
# Epoch 71/100
# 20/20 [==============================] - 2s 88ms/step - loss: 0.0911 - val_loss: 0.0531
# Epoch 72/100
# 20/20 [==============================] - 2s 80ms/step - loss: 0.0939 - val_loss: 0.0589
# Epoch 73/100
# 20/20 [==============================] - 2s 80ms/step - loss: 0.0904 - val_loss: 0.0571
# Epoch 74/100
# 20/20 [==============================] - 2s 81ms/step - loss: 0.0950 - val_loss: 0.0561
# Epoch 75/100
# 20/20 [==============================] - 2s 80ms/step - loss: 0.0895 - val_loss: 0.0559
# Epoch 76/100
# 20/20 [==============================] - 2s 81ms/step - loss: 0.0884 - val_loss: 0.0542
# Epoch 77/100
# 20/20 [==============================] - 2s 88ms/step - loss: 0.0881 - val_loss: 0.0526
# Epoch 78/100
# 20/20 [==============================] - 2s 81ms/step - loss: 0.0890 - val_loss: 0.0534
# Epoch 79/100
# 20/20 [==============================] - 2s 80ms/step - loss: 0.0824 - val_loss: 0.0530
# Epoch 80/100
# 20/20 [==============================] - 2s 79ms/step - loss: 0.0957 - val_loss: 0.0553
# Epoch 81/100
# 20/20 [==============================] - 2s 80ms/step - loss: 0.0893 - val_loss: 0.0563
# Epoch 82/100
# 20/20 [==============================] - 2s 79ms/step - loss: 0.0969 - val_loss: 0.0688
# Epoch 83/100
# 20/20 [==============================] - 2s 80ms/step - loss: 0.0911 - val_loss: 0.0582
# Epoch 84/100
# 20/20 [==============================] - 2s 80ms/step - loss: 0.0899 - val_loss: 0.0555
# Epoch 85/100
# 20/20 [==============================] - 2s 80ms/step - loss: 0.0859 - val_loss: 0.0558
# Epoch 86/100
# 20/20 [==============================] - 2s 81ms/step - loss: 0.0852 - val_loss: 0.0542
# Epoch 87/100
# 20/20 [==============================] - 2s 80ms/step - loss: 0.0774 - val_loss: 0.0529
# Epoch 88/100
# 20/20 [==============================] - 2s 80ms/step - loss: 0.0899 - val_loss: 0.0564
# Epoch 89/100
# 20/20 [==============================] - ETA: 0s - loss: 0.0891Restoring model weights from the end of the best epoch: 77.
# 20/20 [==============================] - 2s 90ms/step - loss: 0.0891 - val_loss: 0.0557
# Epoch 89: early stopping

# %%
_, X_test, _, y_test, input_shape = load_dataset('contrast', dataset_paths_pairs, is_train_process=False)
predictions = contrast_model.predict(X_test)
# Out:
# 7/7 [==============================] - 1s 144ms/step

# %% [markdown]
# #3 Seconds Files

# %%
triplets_path = '../datasets/3_sec_datasets/triplets_dataset'
dataset_paths_triplet = {f"{dataset}_{type}": f"{triplets_path}/{type}_{dataset}.npy"
                            for dataset in ['train', 'val', 'test'] for type in ['anchors', 'positives', 'negatives']}

pairs_path = '../datasets/3_sec_datasets/pairs_dataset/'
dataset_paths_pairs = {f"{d_type}_{dataset}": f"{pairs_path}{d_type}_{dataset}_pairs.npy" for dataset in ['train', 'val', 'test'] for d_type in ['X', 'y']}

# %% [markdown]
# ##Triplet Loss Model

# %%
X_train, X_test, y_train, y_test, input_shape = load_dataset('triplet', dataset_paths_triplet, is_train_process=True)
datasets = [X_train, X_test, y_train, y_test]
print("Datasets are loaded", input_shape)
# Out:
# Datasets are loaded (6387, 231, 232, 3)

# %%
triplet_model = fit_and_save_model(datasets, input_shape, batch_size=64, loss_method='triplet', epochs=100, dtype='3_sec')
# Out:
# Model is created, starting train process ...
# Epoch 1/100
# 100/100 [==============================] - 32s 282ms/step - loss: 7.3242 - val_loss: 0.8231
# Epoch 2/100
# 100/100 [==============================] - 22s 223ms/step - loss: 2.5769 - val_loss: 0.0456
# Epoch 3/100
# 100/100 [==============================] - 22s 221ms/step - loss: 1.1776 - val_loss: 0.3373
# Epoch 4/100
# 100/100 [==============================] - 22s 222ms/step - loss: 0.6440 - val_loss: 0.2443
# Epoch 5/100
# 100/100 [==============================] - 22s 224ms/step - loss: 0.3563 - val_loss: 0.0347
# Epoch 6/100
# 100/100 [==============================] - 22s 224ms/step - loss: 0.2572 - val_loss: 0.0233
# Epoch 7/100
# 100/100 [==============================] - 22s 223ms/step - loss: 0.2233 - val_loss: 0.0088
# Epoch 8/100
# 100/100 [==============================] - 22s 223ms/step - loss: 0.1453 - val_loss: 0.0045
# Epoch 9/100
# 100/100 [==============================] - 22s 223ms/step - loss: 0.1160 - val_loss: 0.0038
# Epoch 10/100
# 100/100 [==============================] - 22s 221ms/step - loss: 0.0986 - val_loss: 0.0080
# Epoch 11/100
# 100/100 [==============================] - 22s 221ms/step - loss: 0.0670 - val_loss: 0.0094
# Epoch 12/100
# 100/100 [==============================] - 22s 221ms/step - loss: 0.0734 - val_loss: 0.0068
# Epoch 13/100
# 100/100 [==============================] - 22s 221ms/step - loss: 0.0584 - val_loss: 0.0068
# Epoch 14/100
# 100/100 [==============================] - 22s 223ms/step - loss: 0.0719 - val_loss: 7.9901e-04
# Epoch 15/100
# 100/100 [==============================] - 22s 224ms/step - loss: 0.0408 - val_loss: 0.0000e+00
# Epoch 16/100
# 100/100 [==============================] - 22s 222ms/step - loss: 0.0378 - val_loss: 0.0000e+00
# Epoch 17/100
# 100/100 [==============================] - 22s 222ms/step - loss: 0.0480 - val_loss: 0.0018
# Epoch 18/100
# 100/100 [==============================] - 22s 222ms/step - loss: 0.0285 - val_loss: 0.0073
# Epoch 19/100
# 100/100 [==============================] - 22s 222ms/step - loss: 0.0307 - val_loss: 0.0048
# Epoch 20/100
# 100/100 [==============================] - 22s 221ms/step - loss: 0.0293 - val_loss: 0.0036
# Epoch 21/100
# 100/100 [==============================] - 22s 221ms/step - loss: 0.0358 - val_loss: 0.0053
# Epoch 22/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0198Restoring model weights from the end of the best epoch: 15.
# 100/100 [==============================] - 22s 224ms/step - loss: 0.0198 - val_loss: 0.0059
# Epoch 22: early stopping

# %%
_, X_test, _, y_test, input_shape = load_dataset('triplet', dataset_paths_triplet, is_train_process=False)
predictions = triplet_model.predict(X_test)

# %%
X_test.shape

# %% [markdown]
# ##Contrastive Loss Model

# %%
X_train, X_test, y_train, y_test, input_shape = load_dataset('contrast', dataset_paths_pairs, is_train_process=True)
datasets = [X_train, X_test, y_train, y_test]
print("Datasets are loaded", input_shape)
# Out:
# Datasets are loaded (231, 232, 3)

# %%
contrast_model = fit_and_save_model(datasets, input_shape, batch_size=64, loss_method='contrast', epochs=100, dtype='3_sec')
# Out:
# Model is created, starting train process ...
# Epoch 1/100
# 100/100 [==============================] - 40s 287ms/step - loss: 0.7047 - val_loss: 0.1316
# Epoch 2/100
# 100/100 [==============================] - 15s 151ms/step - loss: 0.4327 - val_loss: 0.1022
# Epoch 3/100
# 100/100 [==============================] - 15s 150ms/step - loss: 0.2527 - val_loss: 0.0755
# Epoch 4/100
# 100/100 [==============================] - 15s 150ms/step - loss: 0.1526 - val_loss: 0.0600
# Epoch 5/100
# 100/100 [==============================] - 15s 151ms/step - loss: 0.1129 - val_loss: 0.0546
# Epoch 6/100
# 100/100 [==============================] - 15s 150ms/step - loss: 0.1001 - val_loss: 0.0511
# Epoch 7/100
# 100/100 [==============================] - 15s 151ms/step - loss: 0.0915 - val_loss: 0.0485
# Epoch 8/100
# 100/100 [==============================] - 15s 150ms/step - loss: 0.0843 - val_loss: 0.0470
# Epoch 9/100
# 100/100 [==============================] - 15s 149ms/step - loss: 0.0841 - val_loss: 0.0499
# Epoch 10/100
# 100/100 [==============================] - 15s 150ms/step - loss: 0.0754 - val_loss: 0.0454
# Epoch 11/100
# 100/100 [==============================] - 15s 149ms/step - loss: 0.0696 - val_loss: 0.0459
# Epoch 12/100
# 100/100 [==============================] - 15s 150ms/step - loss: 0.0714 - val_loss: 0.0452
# Epoch 13/100
# 100/100 [==============================] - 15s 149ms/step - loss: 0.0828 - val_loss: 0.0511
# Epoch 14/100
# 100/100 [==============================] - 15s 151ms/step - loss: 0.0687 - val_loss: 0.0446
# Epoch 15/100
# 100/100 [==============================] - 15s 149ms/step - loss: 0.0640 - val_loss: 0.0450
# Epoch 16/100
# 100/100 [==============================] - 15s 151ms/step - loss: 0.0630 - val_loss: 0.0440
# Epoch 17/100
# 100/100 [==============================] - 15s 150ms/step - loss: 0.0650 - val_loss: 0.0485
# Epoch 18/100
# 100/100 [==============================] - 15s 151ms/step - loss: 0.0642 - val_loss: 0.0427
# Epoch 19/100
# 100/100 [==============================] - 15s 149ms/step - loss: 0.0668 - val_loss: 0.0490
# Epoch 20/100
# 100/100 [==============================] - 15s 151ms/step - loss: 0.0612 - val_loss: 0.0416
# Epoch 21/100
# 100/100 [==============================] - 15s 151ms/step - loss: 0.0582 - val_loss: 0.0406
# Epoch 22/100
# 100/100 [==============================] - 15s 152ms/step - loss: 0.0557 - val_loss: 0.0392
# Epoch 23/100
# 100/100 [==============================] - 15s 151ms/step - loss: 0.0498 - val_loss: 0.0396
# Epoch 24/100
# 100/100 [==============================] - 15s 149ms/step - loss: 0.0513 - val_loss: 0.0394
# Epoch 25/100
# 100/100 [==============================] - 15s 149ms/step - loss: 0.0511 - val_loss: 0.0402
# Epoch 26/100
# 100/100 [==============================] - 15s 149ms/step - loss: 0.0494 - val_loss: 0.0392
# Epoch 27/100
# 100/100 [==============================] - 15s 150ms/step - loss: 0.0487 - val_loss: 0.0390
# Epoch 28/100
# 100/100 [==============================] - 15s 151ms/step - loss: 0.0475 - val_loss: 0.0389
# Epoch 29/100
# 100/100 [==============================] - 15s 150ms/step - loss: 0.0458 - val_loss: 0.0389
# Epoch 30/100
# 100/100 [==============================] - 15s 149ms/step - loss: 0.0547 - val_loss: 0.0398
# Epoch 31/100
# 100/100 [==============================] - 15s 149ms/step - loss: 0.0474 - val_loss: 0.0391
# Epoch 32/100
# 100/100 [==============================] - 15s 151ms/step - loss: 0.0459 - val_loss: 0.0387
# Epoch 33/100
# 100/100 [==============================] - 15s 150ms/step - loss: 0.0443 - val_loss: 0.0388
# Epoch 34/100
# 100/100 [==============================] - 15s 150ms/step - loss: 0.0449 - val_loss: 0.0386
# Epoch 35/100
# 100/100 [==============================] - 15s 150ms/step - loss: 0.0444 - val_loss: 0.0385
# Epoch 36/100
# 100/100 [==============================] - 15s 149ms/step - loss: 0.0485 - val_loss: 0.0390
# Epoch 37/100
# 100/100 [==============================] - 15s 149ms/step - loss: 0.0453 - val_loss: 0.0386
# Epoch 38/100
# 100/100 [==============================] - 15s 148ms/step - loss: 0.0434 - val_loss: 0.0386
# Epoch 39/100
# 100/100 [==============================] - 15s 148ms/step - loss: 0.0425 - val_loss: 0.0386
# Epoch 40/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0423Restoring model weights from the end of the best epoch: 35.
# 100/100 [==============================] - 15s 150ms/step - loss: 0.0423 - val_loss: 0.0387
# Epoch 40: early stopping

# %%
X_train[0].shape
# Out:
# (6387, 231, 232, 3)

# %%
_, X_test, _, y_test, input_shape = load_dataset('contrast', dataset_paths_pairs, is_train_process=False)
predictions = contrast_model.predict(X_test)
# Out:
# 32/32 [==============================] - 3s 38ms/step
