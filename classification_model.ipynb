# %% [markdown]
# #Imports and Configurations

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd drive/MyDrive/Audio_Final_Project/Classifier_Network
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Audio_Final_Project/Classifier_Network

# %%
import os
import pickle
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import BatchNormalization, Activation
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# #Network Architecture

# %%
def build_conv_branch(name, input_shape):
    model = Sequential(name=name)
    # Layer 1
    model.add(Conv2D(64, (3, 3), padding='same', kernel_initializer='he_uniform', input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    # Layer 2
    model.add(Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    # Layer 3
    model.add(Conv2D(128, (3, 3), padding='same', kernel_initializer='he_uniform'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    return model


def create_conv_network(input_shape, num_classes, branch_name, preload_weights, dropout_rate=0.5, weights_path=None, freeze_pretrained=False):
    input_1 = Input(input_shape)
    branch_1 = build_conv_branch(name=branch_name, input_shape=input_shape)

    if preload_weights and weights_path:
        branch_1.load_weights(weights_path)
        if freeze_pretrained:
            for layer in branch_1.layers:
                layer.trainable = False

        branch_1 = branch_1(input_1)

    else:
        branch_1 = branch_1(input_1)

    x = Flatten()(branch_1)
    x = Dense(512, kernel_initializer='he_uniform')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(dropout_rate)(x)

    x = Dense(256, kernel_initializer='he_uniform')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(dropout_rate)(x)

    x = Dense(128, kernel_initializer='he_uniform')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(dropout_rate)(x)

    output = Dense(num_classes, activation='softmax')(x)
    model = Model(inputs=input_1, outputs=output)

    return model

# %% [markdown]
# #ImageDataGenerators Initialization

# %%
def load_classification_dataset(path_to_dataset='../datasets/B_W_datasets/classification_dataset', is_train_process=True):
    if is_train_process:
        X_train = np.load(os.path.join(path_to_dataset, 'X_train.npy'))
        y_train = np.load(os.path.join(path_to_dataset, 'y_train.npy'))
        X_validation = np.load(os.path.join(path_to_dataset, 'X_validation.npy'))
        y_validation = np.load(os.path.join(path_to_dataset, 'y_validation.npy'))
        X_test = []
        y_test = []

        input_shape = X_train.shape[1:]
    else:
        X_test = np.load(os.path.join(path_to_dataset, 'X_test.npy'))
        y_test = np.load(os.path.join(path_to_dataset, 'y_test.npy'))
        X_train = []
        y_train = []
        X_validation = []
        y_validation = []
        input_shape = X_test.shape[1:]

    return X_train, y_train, X_test, y_test, X_validation, y_validation, input_shape

# %%
# def create_generators(base_dir, batch_size):
#     train_dir = os.path.join(base_dir, 'train')
#     validation_dir = os.path.join(base_dir, 'validation')
#     test_dir = os.path.join(base_dir, 'test')
#     datagen = ImageDataGenerator()
#     train_generator = datagen.flow_from_directory(
#         train_dir,
#         target_size=(231, 232),
#         batch_size=batch_size,
#         class_mode='categorical',
#         shuffle=True
#     )
#     validation_generator = datagen.flow_from_directory(
#         validation_dir,
#         target_size=(231, 232),
#         batch_size=batch_size,
#         class_mode='categorical',
#         shuffle=True
#     )
#     test_generator = datagen.flow_from_directory(
#         test_dir,
#         target_size=(231, 232),
#         batch_size=batch_size,
#         class_mode='categorical',
#         shuffle=True
#     )
#     return train_generator, validation_generator, test_generator

# %%
def decode_image(filename, label, image_size=(231, 232)):
    image = tf.io.read_file(filename)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, image_size)
    image = image / 255.0  # Normalize to [0, 1] range
    return image, label

def create_dataset(directory, class_names_to_index, batch_size, image_size=(231, 232)):
    # Create a lookup table
    keys_tensor = tf.constant(list(class_names_to_index.keys()))
    vals_tensor = tf.constant(list(class_names_to_index.values()))
    table_init = tf.lookup.KeyValueTensorInitializer(keys_tensor, vals_tensor)
    table = tf.lookup.StaticHashTable(table_init, default_value=-1)

    def process_path(file_path):
        label = get_class_name(file_path)
        label = table.lookup(label)  # Look up the integer label from the class name
        return file_path, label

    dataset = tf.data.Dataset.list_files(os.path.join(directory, '*/*'))
    dataset = dataset.map(process_path, num_parallel_calls=tf.data.AUTOTUNE)

    # Decode the image and one-hot encode the label
    dataset = dataset.map(lambda x, y: (decode_image(x, y, image_size), tf.one_hot(y, depth=len(class_names_to_index))),
                          num_parallel_calls=tf.data.AUTOTUNE)

    dataset = dataset.shuffle(buffer_size=1000).batch(batch_size).prefetch(buffer_size=tf.data.AUTOTUNE)
    return dataset

def get_class_name(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2]  # Adjust this index based on your file path structure


# Example usage
base_dir='../datasets/30_sec_datasets'
batch_size = 32
class_names = os.listdir(os.path.join(base_dir, 'train'))
class_names_to_index = {name: index for index, name in enumerate(class_names)}

# %% [markdown]
# #Model Fit Function

# %%
def fit_and_save_model(datasets, batch_size, model, loss_method, epochs, dtype):
    assert dtype in ['30_sec', '3_sec'], "dtype must be '30_sec' or '3_sec'"
    early_stopping = EarlyStopping(monitor='val_loss', patience=7, verbose=1, mode='min', restore_best_weights=True)
    # optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate=0.0001)
    optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate=0.00005)

    loss = keras.losses.categorical_crossentropy
    metrics = [keras.metrics.categorical_accuracy]

    model.compile(loss=loss, optimizer=optimizer, metrics=metrics)
    # train_gen, val_gen, test_gen = datasets
    # history = model.fit(train_gen, validation_data=val_gen, verbose=1,
    #                     epochs=epochs, callbacks=[early_stopping])
    X_train, y_train, X_validation, y_validation = datasets
    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation),
                        verbose=1, epochs=epochs, callbacks=[early_stopping],
                        batch_size=batch_size, shuffle=True)

    pickle.dump(history.history, open(f'{dtype}/{loss_method}_classifier_history.pkl', 'wb'))

    return model

# %% [markdown]
# #30 Seconds Files

# %%
path_to_dataset ='../datasets/30_sec_datasets/classifier_dataset'
batch_size = 64
X_train, y_train, _, _, X_validation, y_validation, input_shape = load_classification_dataset(path_to_dataset, is_train_process=True)
datasets = [X_train, y_train, X_validation, y_validation]

# %%
X_train, y_train, _, _, X_validation, y_validation, input_shape = load_classification_dataset(path_to_dataset, is_train_process=True)
train_indices = np.arange(X_train.shape[0])
np.random.shuffle(train_indices)
X_train_shuffled = X_train[train_indices]
y_train_shuffled = y_train[train_indices]

validation_indices = np.arange(X_validation.shape[0])
np.random.shuffle(validation_indices)
X_validation_shuffled = X_validation[validation_indices]
y_validation_shuffled = y_validation[validation_indices]

datasets = [X_train_shuffled, y_train_shuffled, X_validation_shuffled, y_validation_shuffled]

# %%
# path_to_dataset ='../datasets/30_sec_datasets'
# batch_size = 64
# train_gen, val_gen, test_gen = create_generators(path_to_dataset, batch_size)
# datasets = [train_gen, val_gen, test_gen]
# input_shape = (231, 232, 3)

# %% [markdown]
# ##Triplet Loss Based

# %%
model = create_conv_network(input_shape=input_shape, num_classes=10, branch_name='triplet_branch',
                            preload_weights=True, weights_path='../Siamese_Network/30_sec/triplet_branch.h5')
triplet_based_classifier = fit_and_save_model(datasets, batch_size, model, 'triplet', epochs=100, dtype='30_sec')
# Out:
# Epoch 1/100
# 10/10 [==============================] - 15s 936ms/step - loss: 2.8297 - categorical_accuracy: 0.1252 - val_loss: 2.3557 - val_categorical_accuracy: 0.1187
# Epoch 2/100
# 10/10 [==============================] - 1s 99ms/step - loss: 2.4761 - categorical_accuracy: 0.1925 - val_loss: 1.9906 - val_categorical_accuracy: 0.2438
# Epoch 3/100
# 10/10 [==============================] - 1s 98ms/step - loss: 2.2254 - categorical_accuracy: 0.2410 - val_loss: 1.8290 - val_categorical_accuracy: 0.3313
# Epoch 4/100
# 10/10 [==============================] - 1s 96ms/step - loss: 2.1490 - categorical_accuracy: 0.2582 - val_loss: 1.7643 - val_categorical_accuracy: 0.4187
# Epoch 5/100
# 10/10 [==============================] - 1s 97ms/step - loss: 2.0157 - categorical_accuracy: 0.2942 - val_loss: 1.7053 - val_categorical_accuracy: 0.5063
# Epoch 6/100
# 10/10 [==============================] - 1s 96ms/step - loss: 1.8836 - categorical_accuracy: 0.3161 - val_loss: 1.6715 - val_categorical_accuracy: 0.4750
# Epoch 7/100
# 10/10 [==============================] - 1s 97ms/step - loss: 1.8219 - categorical_accuracy: 0.3772 - val_loss: 1.6362 - val_categorical_accuracy: 0.4750
# Epoch 8/100
# 10/10 [==============================] - 1s 99ms/step - loss: 1.6817 - categorical_accuracy: 0.4194 - val_loss: 1.6123 - val_categorical_accuracy: 0.4750
# Epoch 9/100
# 10/10 [==============================] - 1s 99ms/step - loss: 1.6361 - categorical_accuracy: 0.4288 - val_loss: 1.5859 - val_categorical_accuracy: 0.5125
# Epoch 10/100
# 10/10 [==============================] - 1s 84ms/step - loss: 1.4880 - categorical_accuracy: 0.4710 - val_loss: 1.5937 - val_categorical_accuracy: 0.5000
# Epoch 11/100
# 10/10 [==============================] - 1s 83ms/step - loss: 1.4838 - categorical_accuracy: 0.4695 - val_loss: 1.6010 - val_categorical_accuracy: 0.5000
# Epoch 12/100
# 10/10 [==============================] - 1s 82ms/step - loss: 1.4274 - categorical_accuracy: 0.5039 - val_loss: 1.5936 - val_categorical_accuracy: 0.4938
# Epoch 13/100
# 10/10 [==============================] - 1s 83ms/step - loss: 1.3874 - categorical_accuracy: 0.5086 - val_loss: 1.5913 - val_categorical_accuracy: 0.5000
# Epoch 14/100
# 10/10 [==============================] - 1s 96ms/step - loss: 1.3565 - categorical_accuracy: 0.5352 - val_loss: 1.5736 - val_categorical_accuracy: 0.4938
# Epoch 15/100
# 10/10 [==============================] - 1s 97ms/step - loss: 1.2681 - categorical_accuracy: 0.5790 - val_loss: 1.5537 - val_categorical_accuracy: 0.5250
# Epoch 16/100
# 10/10 [==============================] - 1s 97ms/step - loss: 1.1659 - categorical_accuracy: 0.6260 - val_loss: 1.5344 - val_categorical_accuracy: 0.5188
# Epoch 17/100
# 10/10 [==============================] - 1s 96ms/step - loss: 1.1253 - categorical_accuracy: 0.6416 - val_loss: 1.5312 - val_categorical_accuracy: 0.5375
# Epoch 18/100
# 10/10 [==============================] - 1s 82ms/step - loss: 1.1472 - categorical_accuracy: 0.6354 - val_loss: 1.5325 - val_categorical_accuracy: 0.5063
# Epoch 19/100
# 10/10 [==============================] - 1s 96ms/step - loss: 1.0664 - categorical_accuracy: 0.6510 - val_loss: 1.4906 - val_categorical_accuracy: 0.5437
# Epoch 20/100
# 10/10 [==============================] - 1s 96ms/step - loss: 1.0596 - categorical_accuracy: 0.6808 - val_loss: 1.4564 - val_categorical_accuracy: 0.5750
# Epoch 21/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.9800 - categorical_accuracy: 0.6917 - val_loss: 1.4440 - val_categorical_accuracy: 0.5500
# Epoch 22/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.9849 - categorical_accuracy: 0.7042 - val_loss: 1.4434 - val_categorical_accuracy: 0.5188
# Epoch 23/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.9409 - categorical_accuracy: 0.7121 - val_loss: 1.4322 - val_categorical_accuracy: 0.5125
# Epoch 24/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.8859 - categorical_accuracy: 0.7527 - val_loss: 1.4318 - val_categorical_accuracy: 0.5188
# Epoch 25/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.8823 - categorical_accuracy: 0.7340 - val_loss: 1.4345 - val_categorical_accuracy: 0.5250
# Epoch 26/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.8310 - categorical_accuracy: 0.7746 - val_loss: 1.3940 - val_categorical_accuracy: 0.5437
# Epoch 27/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.8534 - categorical_accuracy: 0.7543 - val_loss: 1.3450 - val_categorical_accuracy: 0.5625
# Epoch 28/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.8523 - categorical_accuracy: 0.7731 - val_loss: 1.3325 - val_categorical_accuracy: 0.5938
# Epoch 29/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.7784 - categorical_accuracy: 0.8138 - val_loss: 1.3070 - val_categorical_accuracy: 0.5938
# Epoch 30/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.8113 - categorical_accuracy: 0.7825 - val_loss: 1.2552 - val_categorical_accuracy: 0.6375
# Epoch 31/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.7479 - categorical_accuracy: 0.8153 - val_loss: 1.2472 - val_categorical_accuracy: 0.6750
# Epoch 32/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.7605 - categorical_accuracy: 0.8044 - val_loss: 1.2270 - val_categorical_accuracy: 0.6750
# Epoch 33/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.7029 - categorical_accuracy: 0.8185 - val_loss: 1.2366 - val_categorical_accuracy: 0.6750
# Epoch 34/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.7059 - categorical_accuracy: 0.8451 - val_loss: 1.2466 - val_categorical_accuracy: 0.6375
# Epoch 35/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.6622 - categorical_accuracy: 0.8341 - val_loss: 1.2563 - val_categorical_accuracy: 0.6438
# Epoch 36/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.6526 - categorical_accuracy: 0.8576 - val_loss: 1.2344 - val_categorical_accuracy: 0.6687
# Epoch 37/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.6242 - categorical_accuracy: 0.8717 - val_loss: 1.1953 - val_categorical_accuracy: 0.6625
# Epoch 38/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.6349 - categorical_accuracy: 0.8638 - val_loss: 1.1787 - val_categorical_accuracy: 0.6625
# Epoch 39/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.6395 - categorical_accuracy: 0.8607 - val_loss: 1.1851 - val_categorical_accuracy: 0.6687
# Epoch 40/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.5974 - categorical_accuracy: 0.8779 - val_loss: 1.1844 - val_categorical_accuracy: 0.6625
# Epoch 41/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.5941 - categorical_accuracy: 0.8732 - val_loss: 1.1580 - val_categorical_accuracy: 0.6875
# Epoch 42/100
# 10/10 [==============================] - 1s 99ms/step - loss: 0.5793 - categorical_accuracy: 0.8795 - val_loss: 1.1447 - val_categorical_accuracy: 0.6938
# Epoch 43/100
# 10/10 [==============================] - 1s 99ms/step - loss: 0.5435 - categorical_accuracy: 0.9030 - val_loss: 1.1394 - val_categorical_accuracy: 0.6938
# Epoch 44/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.5417 - categorical_accuracy: 0.8936 - val_loss: 1.1193 - val_categorical_accuracy: 0.6812
# Epoch 45/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.5009 - categorical_accuracy: 0.9124 - val_loss: 1.1062 - val_categorical_accuracy: 0.6875
# Epoch 46/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.5309 - categorical_accuracy: 0.8936 - val_loss: 1.1043 - val_categorical_accuracy: 0.6875
# Epoch 47/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.5396 - categorical_accuracy: 0.8905 - val_loss: 1.1001 - val_categorical_accuracy: 0.6875
# Epoch 48/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.4923 - categorical_accuracy: 0.9124 - val_loss: 1.1052 - val_categorical_accuracy: 0.6812
# Epoch 49/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.4540 - categorical_accuracy: 0.9264 - val_loss: 1.1060 - val_categorical_accuracy: 0.6750
# Epoch 50/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.4835 - categorical_accuracy: 0.9264 - val_loss: 1.0888 - val_categorical_accuracy: 0.6812
# Epoch 51/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.4846 - categorical_accuracy: 0.9155 - val_loss: 1.0857 - val_categorical_accuracy: 0.6812
# Epoch 52/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.4553 - categorical_accuracy: 0.9139 - val_loss: 1.0805 - val_categorical_accuracy: 0.6938
# Epoch 53/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.4409 - categorical_accuracy: 0.9233 - val_loss: 1.0750 - val_categorical_accuracy: 0.6812
# Epoch 54/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.4597 - categorical_accuracy: 0.9077 - val_loss: 1.0587 - val_categorical_accuracy: 0.6875
# Epoch 55/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.4613 - categorical_accuracy: 0.9139 - val_loss: 1.0412 - val_categorical_accuracy: 0.6938
# Epoch 56/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.4320 - categorical_accuracy: 0.9264 - val_loss: 1.0371 - val_categorical_accuracy: 0.7000
# Epoch 57/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.4005 - categorical_accuracy: 0.9468 - val_loss: 1.0311 - val_categorical_accuracy: 0.7125
# Epoch 58/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.4294 - categorical_accuracy: 0.9202 - val_loss: 1.0107 - val_categorical_accuracy: 0.7188
# Epoch 59/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.3997 - categorical_accuracy: 0.9546 - val_loss: 0.9958 - val_categorical_accuracy: 0.7063
# Epoch 60/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.4023 - categorical_accuracy: 0.9499 - val_loss: 0.9821 - val_categorical_accuracy: 0.7063
# Epoch 61/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.3880 - categorical_accuracy: 0.9452 - val_loss: 0.9892 - val_categorical_accuracy: 0.7125
# Epoch 62/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.3732 - categorical_accuracy: 0.9499 - val_loss: 0.9840 - val_categorical_accuracy: 0.7188
# Epoch 63/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.3887 - categorical_accuracy: 0.9421 - val_loss: 1.0010 - val_categorical_accuracy: 0.7125
# Epoch 64/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.3533 - categorical_accuracy: 0.9499 - val_loss: 1.0294 - val_categorical_accuracy: 0.7063
# Epoch 65/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.3347 - categorical_accuracy: 0.9718 - val_loss: 1.0211 - val_categorical_accuracy: 0.6938
# Epoch 66/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.3541 - categorical_accuracy: 0.9437 - val_loss: 1.0078 - val_categorical_accuracy: 0.7000
# Epoch 67/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.3241 - categorical_accuracy: 0.9687 - val_loss: 1.0086 - val_categorical_accuracy: 0.7000
# Epoch 68/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.3374 - categorical_accuracy: 0.9577 - val_loss: 0.9985 - val_categorical_accuracy: 0.7188
# Epoch 69/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.3449 - categorical_accuracy: 0.9624 - val_loss: 0.9906 - val_categorical_accuracy: 0.7250
# Epoch 70/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.3383 - categorical_accuracy: 0.9687 - val_loss: 0.9987 - val_categorical_accuracy: 0.7125
# Epoch 71/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.3074 - categorical_accuracy: 0.9703 - val_loss: 1.0084 - val_categorical_accuracy: 0.7063
# Epoch 72/100
# 10/10 [==============================] - ETA: 0s - loss: 0.3456 - categorical_accuracy: 0.9421Restoring model weights from the end of the best epoch: 60.
# 10/10 [==============================] - 1s 103ms/step - loss: 0.3456 - categorical_accuracy: 0.9421 - val_loss: 1.0138 - val_categorical_accuracy: 0.7063
# Epoch 72: early stopping

# %%
_, _, X_test, y_test, _, _, input_shape = load_classification_dataset(path_to_dataset, is_train_process=False)
evaluation = triplet_based_classifier.evaluate(X_test, y_test)
predictions = triplet_based_classifier.predict(X_test)
pickle.dump(predictions, open('test_classifications/triplet_30_sec.pkl', 'wb'))

# %% [markdown]
# ##Contrastive Loss Based

# %%
model = create_conv_network(input_shape=input_shape, num_classes=10, branch_name='contrast_branch',
                            preload_weights=True, weights_path='../Siamese_Network/30_sec/contrast_branch.h5')
contrast_based_classifier = fit_and_save_model(datasets, batch_size, model, 'contrast', epochs=100, dtype='30_sec')
# Out:
# Epoch 1/100
# 10/10 [==============================] - 18s 944ms/step - loss: 2.6739 - categorical_accuracy: 0.1252 - val_loss: 3.5666 - val_categorical_accuracy: 0.2812
# Epoch 2/100
# 10/10 [==============================] - 1s 83ms/step - loss: 2.4458 - categorical_accuracy: 0.1847 - val_loss: 3.8478 - val_categorical_accuracy: 0.2250
# Epoch 3/100
# 10/10 [==============================] - 1s 97ms/step - loss: 2.3640 - categorical_accuracy: 0.2113 - val_loss: 3.2573 - val_categorical_accuracy: 0.2750
# Epoch 4/100
# 10/10 [==============================] - 1s 99ms/step - loss: 2.2705 - categorical_accuracy: 0.2363 - val_loss: 2.6543 - val_categorical_accuracy: 0.3187
# Epoch 5/100
# 10/10 [==============================] - 1s 97ms/step - loss: 2.1195 - categorical_accuracy: 0.2676 - val_loss: 2.2739 - val_categorical_accuracy: 0.3313
# Epoch 6/100
# 10/10 [==============================] - 1s 97ms/step - loss: 2.0704 - categorical_accuracy: 0.2801 - val_loss: 1.9405 - val_categorical_accuracy: 0.3250
# Epoch 7/100
# 10/10 [==============================] - 1s 98ms/step - loss: 1.9664 - categorical_accuracy: 0.3052 - val_loss: 1.7399 - val_categorical_accuracy: 0.3562
# Epoch 8/100
# 10/10 [==============================] - 1s 98ms/step - loss: 1.9345 - categorical_accuracy: 0.3552 - val_loss: 1.6665 - val_categorical_accuracy: 0.4000
# Epoch 9/100
# 10/10 [==============================] - 1s 97ms/step - loss: 1.8331 - categorical_accuracy: 0.3615 - val_loss: 1.6060 - val_categorical_accuracy: 0.3812
# Epoch 10/100
# 10/10 [==============================] - 1s 97ms/step - loss: 1.7722 - categorical_accuracy: 0.3850 - val_loss: 1.5372 - val_categorical_accuracy: 0.3875
# Epoch 11/100
# 10/10 [==============================] - 1s 99ms/step - loss: 1.6325 - categorical_accuracy: 0.4194 - val_loss: 1.4726 - val_categorical_accuracy: 0.4250
# Epoch 12/100
# 10/10 [==============================] - 1s 97ms/step - loss: 1.6315 - categorical_accuracy: 0.4382 - val_loss: 1.4533 - val_categorical_accuracy: 0.4375
# Epoch 13/100
# 10/10 [==============================] - 1s 98ms/step - loss: 1.5999 - categorical_accuracy: 0.4570 - val_loss: 1.4345 - val_categorical_accuracy: 0.4688
# Epoch 14/100
# 10/10 [==============================] - 1s 84ms/step - loss: 1.4719 - categorical_accuracy: 0.5023 - val_loss: 1.4462 - val_categorical_accuracy: 0.4625
# Epoch 15/100
# 10/10 [==============================] - 1s 97ms/step - loss: 1.4006 - categorical_accuracy: 0.5430 - val_loss: 1.3925 - val_categorical_accuracy: 0.5188
# Epoch 16/100
# 10/10 [==============================] - 1s 98ms/step - loss: 1.3287 - categorical_accuracy: 0.5587 - val_loss: 1.3604 - val_categorical_accuracy: 0.5813
# Epoch 17/100
# 10/10 [==============================] - 1s 97ms/step - loss: 1.2722 - categorical_accuracy: 0.5900 - val_loss: 1.3510 - val_categorical_accuracy: 0.6062
# Epoch 18/100
# 10/10 [==============================] - 1s 97ms/step - loss: 1.1787 - categorical_accuracy: 0.6213 - val_loss: 1.2916 - val_categorical_accuracy: 0.6375
# Epoch 19/100
# 10/10 [==============================] - 1s 84ms/step - loss: 1.2331 - categorical_accuracy: 0.5884 - val_loss: 1.3268 - val_categorical_accuracy: 0.6062
# Epoch 20/100
# 10/10 [==============================] - 1s 84ms/step - loss: 1.1549 - categorical_accuracy: 0.6182 - val_loss: 1.3276 - val_categorical_accuracy: 0.6187
# Epoch 21/100
# 10/10 [==============================] - 1s 99ms/step - loss: 1.1097 - categorical_accuracy: 0.6604 - val_loss: 1.2697 - val_categorical_accuracy: 0.6625
# Epoch 22/100
# 10/10 [==============================] - 1s 98ms/step - loss: 1.0507 - categorical_accuracy: 0.6635 - val_loss: 1.2250 - val_categorical_accuracy: 0.6812
# Epoch 23/100
# 10/10 [==============================] - 1s 97ms/step - loss: 1.0494 - categorical_accuracy: 0.7027 - val_loss: 1.1876 - val_categorical_accuracy: 0.6500
# Epoch 24/100
# 10/10 [==============================] - 1s 98ms/step - loss: 1.0014 - categorical_accuracy: 0.6886 - val_loss: 1.1785 - val_categorical_accuracy: 0.6875
# Epoch 25/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.9699 - categorical_accuracy: 0.6917 - val_loss: 1.1852 - val_categorical_accuracy: 0.6938
# Epoch 26/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.9567 - categorical_accuracy: 0.7089 - val_loss: 1.1896 - val_categorical_accuracy: 0.7188
# Epoch 27/100
# 10/10 [==============================] - 1s 85ms/step - loss: 0.9226 - categorical_accuracy: 0.7449 - val_loss: 1.2157 - val_categorical_accuracy: 0.6875
# Epoch 28/100
# 10/10 [==============================] - 1s 85ms/step - loss: 0.8292 - categorical_accuracy: 0.7746 - val_loss: 1.2548 - val_categorical_accuracy: 0.6875
# Epoch 29/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.8335 - categorical_accuracy: 0.7746 - val_loss: 1.2220 - val_categorical_accuracy: 0.6562
# Epoch 30/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.8284 - categorical_accuracy: 0.7731 - val_loss: 1.1761 - val_categorical_accuracy: 0.6500
# Epoch 31/100
# 10/10 [==============================] - 1s 85ms/step - loss: 0.7999 - categorical_accuracy: 0.7997 - val_loss: 1.2029 - val_categorical_accuracy: 0.6250
# Epoch 32/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.7488 - categorical_accuracy: 0.8200 - val_loss: 1.2145 - val_categorical_accuracy: 0.6062
# Epoch 33/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.7336 - categorical_accuracy: 0.8200 - val_loss: 1.1908 - val_categorical_accuracy: 0.6250
# Epoch 34/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.7206 - categorical_accuracy: 0.8372 - val_loss: 1.2038 - val_categorical_accuracy: 0.6438
# Epoch 35/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.6819 - categorical_accuracy: 0.8482 - val_loss: 1.1656 - val_categorical_accuracy: 0.6500
# Epoch 36/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.6730 - categorical_accuracy: 0.8466 - val_loss: 1.1417 - val_categorical_accuracy: 0.6500
# Epoch 37/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.6963 - categorical_accuracy: 0.8451 - val_loss: 1.1198 - val_categorical_accuracy: 0.6625
# Epoch 38/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.6332 - categorical_accuracy: 0.8482 - val_loss: 1.1397 - val_categorical_accuracy: 0.6313
# Epoch 39/100
# 10/10 [==============================] - 1s 85ms/step - loss: 0.6120 - categorical_accuracy: 0.8732 - val_loss: 1.1478 - val_categorical_accuracy: 0.6375
# Epoch 40/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.6319 - categorical_accuracy: 0.8654 - val_loss: 1.1404 - val_categorical_accuracy: 0.6313
# Epoch 41/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.5925 - categorical_accuracy: 0.8717 - val_loss: 1.1390 - val_categorical_accuracy: 0.6313
# Epoch 42/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.6017 - categorical_accuracy: 0.8889 - val_loss: 1.1438 - val_categorical_accuracy: 0.6187
# Epoch 43/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.5662 - categorical_accuracy: 0.8764 - val_loss: 1.1125 - val_categorical_accuracy: 0.6562
# Epoch 44/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.5635 - categorical_accuracy: 0.8951 - val_loss: 1.1154 - val_categorical_accuracy: 0.7000
# Epoch 45/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.5543 - categorical_accuracy: 0.8998 - val_loss: 1.1131 - val_categorical_accuracy: 0.6812
# Epoch 46/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.5660 - categorical_accuracy: 0.8905 - val_loss: 1.1084 - val_categorical_accuracy: 0.6438
# Epoch 47/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.5208 - categorical_accuracy: 0.9061 - val_loss: 1.1268 - val_categorical_accuracy: 0.6375
# Epoch 48/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.5337 - categorical_accuracy: 0.9014 - val_loss: 1.1405 - val_categorical_accuracy: 0.6500
# Epoch 49/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.4792 - categorical_accuracy: 0.9311 - val_loss: 1.1195 - val_categorical_accuracy: 0.6375
# Epoch 50/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.4739 - categorical_accuracy: 0.9233 - val_loss: 1.0887 - val_categorical_accuracy: 0.6562
# Epoch 51/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.4681 - categorical_accuracy: 0.9171 - val_loss: 1.1290 - val_categorical_accuracy: 0.6625
# Epoch 52/100
# 10/10 [==============================] - 1s 85ms/step - loss: 0.4297 - categorical_accuracy: 0.9531 - val_loss: 1.1370 - val_categorical_accuracy: 0.6500
# Epoch 53/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.4335 - categorical_accuracy: 0.9343 - val_loss: 1.1096 - val_categorical_accuracy: 0.6562
# Epoch 54/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.4411 - categorical_accuracy: 0.9296 - val_loss: 1.0726 - val_categorical_accuracy: 0.6562
# Epoch 55/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.4347 - categorical_accuracy: 0.9218 - val_loss: 1.0458 - val_categorical_accuracy: 0.6687
# Epoch 56/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.4210 - categorical_accuracy: 0.9343 - val_loss: 1.0529 - val_categorical_accuracy: 0.6812
# Epoch 57/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.4200 - categorical_accuracy: 0.9468 - val_loss: 1.0625 - val_categorical_accuracy: 0.6812
# Epoch 58/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.3868 - categorical_accuracy: 0.9484 - val_loss: 1.0656 - val_categorical_accuracy: 0.6938
# Epoch 59/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.4018 - categorical_accuracy: 0.9437 - val_loss: 1.0450 - val_categorical_accuracy: 0.7000
# Epoch 60/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.3920 - categorical_accuracy: 0.9437 - val_loss: 1.0473 - val_categorical_accuracy: 0.6938
# Epoch 61/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.3748 - categorical_accuracy: 0.9405 - val_loss: 1.0603 - val_categorical_accuracy: 0.6938
# Epoch 62/100
# 10/10 [==============================] - 1s 99ms/step - loss: 0.3794 - categorical_accuracy: 0.9405 - val_loss: 1.0109 - val_categorical_accuracy: 0.7125
# Epoch 63/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.3700 - categorical_accuracy: 0.9484 - val_loss: 0.9980 - val_categorical_accuracy: 0.7125
# Epoch 64/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.3634 - categorical_accuracy: 0.9609 - val_loss: 1.0117 - val_categorical_accuracy: 0.7063
# Epoch 65/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.3500 - categorical_accuracy: 0.9562 - val_loss: 1.0148 - val_categorical_accuracy: 0.6938
# Epoch 66/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.3627 - categorical_accuracy: 0.9562 - val_loss: 1.0163 - val_categorical_accuracy: 0.6812
# Epoch 67/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.3545 - categorical_accuracy: 0.9577 - val_loss: 1.0056 - val_categorical_accuracy: 0.6938
# Epoch 68/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.3338 - categorical_accuracy: 0.9656 - val_loss: 0.9839 - val_categorical_accuracy: 0.7000
# Epoch 69/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.3473 - categorical_accuracy: 0.9593 - val_loss: 0.9808 - val_categorical_accuracy: 0.6938
# Epoch 70/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.3155 - categorical_accuracy: 0.9703 - val_loss: 0.9821 - val_categorical_accuracy: 0.6875
# Epoch 71/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.3336 - categorical_accuracy: 0.9640 - val_loss: 0.9926 - val_categorical_accuracy: 0.6875
# Epoch 72/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.3168 - categorical_accuracy: 0.9624 - val_loss: 0.9730 - val_categorical_accuracy: 0.6875
# Epoch 73/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.3174 - categorical_accuracy: 0.9750 - val_loss: 0.9858 - val_categorical_accuracy: 0.6812
# Epoch 74/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.2980 - categorical_accuracy: 0.9640 - val_loss: 0.9806 - val_categorical_accuracy: 0.6750
# Epoch 75/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.3303 - categorical_accuracy: 0.9577 - val_loss: 0.9410 - val_categorical_accuracy: 0.7063
# Epoch 76/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.2823 - categorical_accuracy: 0.9734 - val_loss: 0.9380 - val_categorical_accuracy: 0.7063
# Epoch 77/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.2766 - categorical_accuracy: 0.9812 - val_loss: 0.9399 - val_categorical_accuracy: 0.7125
# Epoch 78/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.2817 - categorical_accuracy: 0.9671 - val_loss: 0.9489 - val_categorical_accuracy: 0.7063
# Epoch 79/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.2730 - categorical_accuracy: 0.9640 - val_loss: 0.9599 - val_categorical_accuracy: 0.6750
# Epoch 80/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.2775 - categorical_accuracy: 0.9781 - val_loss: 0.9504 - val_categorical_accuracy: 0.7000
# Epoch 81/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.2757 - categorical_accuracy: 0.9734 - val_loss: 0.9570 - val_categorical_accuracy: 0.6938
# Epoch 82/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.2630 - categorical_accuracy: 0.9765 - val_loss: 0.9679 - val_categorical_accuracy: 0.6938
# Epoch 83/100
# 10/10 [==============================] - ETA: 0s - loss: 0.2707 - categorical_accuracy: 0.9703Restoring model weights from the end of the best epoch: 76.
# 10/10 [==============================] - 1s 103ms/step - loss: 0.2707 - categorical_accuracy: 0.9703 - val_loss: 0.9648 - val_categorical_accuracy: 0.7000
# Epoch 83: early stopping

# %%
_, _, X_test, y_test, _, _, input_shape = load_classification_dataset(path_to_dataset, is_train_process=False)
evaluation = contrast_based_classifier.evaluate(X_test, y_test)
predictions = contrast_based_classifier.predict(X_test)
pickle.dump(predictions, open('test_classifications/contrastive_30_sec.pkl', 'wb'))
# Out:
# 7/7 [==============================] - 1s 79ms/step - loss: 1.0638 - categorical_accuracy: 0.7200
# 7/7 [==============================] - 0s 12ms/step

# %% [markdown]
# ##Regular Loss - No Transfer Learning

# %%
model = create_conv_network(input_shape=input_shape, num_classes=10,
                            branch_name='regular_branch', preload_weights=False)
regular_classifier = fit_and_save_model(datasets, batch_size, model, 'regular', epochs=100, dtype='30_sec')
# Out:
# Epoch 1/100
# 10/10 [==============================] - 3s 183ms/step - loss: 2.8901 - categorical_accuracy: 0.1377 - val_loss: 3.2612 - val_categorical_accuracy: 0.1000
# Epoch 2/100
# 10/10 [==============================] - 1s 99ms/step - loss: 2.5708 - categorical_accuracy: 0.1768 - val_loss: 2.5424 - val_categorical_accuracy: 0.1000
# Epoch 3/100
# 10/10 [==============================] - 1s 98ms/step - loss: 2.3421 - categorical_accuracy: 0.2097 - val_loss: 2.3244 - val_categorical_accuracy: 0.1187
# Epoch 4/100
# 10/10 [==============================] - 1s 96ms/step - loss: 2.1995 - categorical_accuracy: 0.2441 - val_loss: 2.2326 - val_categorical_accuracy: 0.0750
# Epoch 5/100
# 10/10 [==============================] - 1s 99ms/step - loss: 2.0296 - categorical_accuracy: 0.2848 - val_loss: 2.1657 - val_categorical_accuracy: 0.1937
# Epoch 6/100
# 10/10 [==============================] - 1s 97ms/step - loss: 1.9988 - categorical_accuracy: 0.3130 - val_loss: 2.1252 - val_categorical_accuracy: 0.2937
# Epoch 7/100
# 10/10 [==============================] - 1s 98ms/step - loss: 1.8956 - categorical_accuracy: 0.3271 - val_loss: 2.0971 - val_categorical_accuracy: 0.3562
# Epoch 8/100
# 10/10 [==============================] - 1s 99ms/step - loss: 1.8283 - categorical_accuracy: 0.3537 - val_loss: 2.0862 - val_categorical_accuracy: 0.3625
# Epoch 9/100
# 10/10 [==============================] - 1s 98ms/step - loss: 1.6696 - categorical_accuracy: 0.3912 - val_loss: 2.0589 - val_categorical_accuracy: 0.3812
# Epoch 10/100
# 10/10 [==============================] - 1s 98ms/step - loss: 1.5998 - categorical_accuracy: 0.4272 - val_loss: 2.0153 - val_categorical_accuracy: 0.3562
# Epoch 11/100
# 10/10 [==============================] - 1s 96ms/step - loss: 1.5212 - categorical_accuracy: 0.4804 - val_loss: 2.0093 - val_categorical_accuracy: 0.3562
# Epoch 12/100
# 10/10 [==============================] - 1s 83ms/step - loss: 1.4478 - categorical_accuracy: 0.4914 - val_loss: 2.0146 - val_categorical_accuracy: 0.3438
# Epoch 13/100
# 10/10 [==============================] - 1s 83ms/step - loss: 1.3929 - categorical_accuracy: 0.5149 - val_loss: 2.0251 - val_categorical_accuracy: 0.3063
# Epoch 14/100
# 10/10 [==============================] - 1s 83ms/step - loss: 1.4117 - categorical_accuracy: 0.4945 - val_loss: 2.0279 - val_categorical_accuracy: 0.3438
# Epoch 15/100
# 10/10 [==============================] - 1s 84ms/step - loss: 1.3373 - categorical_accuracy: 0.5446 - val_loss: 2.0366 - val_categorical_accuracy: 0.3500
# Epoch 16/100
# 10/10 [==============================] - 1s 82ms/step - loss: 1.2431 - categorical_accuracy: 0.5822 - val_loss: 2.0368 - val_categorical_accuracy: 0.3438
# Epoch 17/100
# 10/10 [==============================] - 1s 82ms/step - loss: 1.2029 - categorical_accuracy: 0.5994 - val_loss: 2.0228 - val_categorical_accuracy: 0.3562
# Epoch 18/100
# 10/10 [==============================] - 1s 84ms/step - loss: 1.1644 - categorical_accuracy: 0.5884 - val_loss: 2.0114 - val_categorical_accuracy: 0.3625
# Epoch 19/100
# 10/10 [==============================] - 1s 98ms/step - loss: 1.2225 - categorical_accuracy: 0.6009 - val_loss: 2.0041 - val_categorical_accuracy: 0.3562
# Epoch 20/100
# 10/10 [==============================] - 1s 83ms/step - loss: 1.0471 - categorical_accuracy: 0.6761 - val_loss: 2.0108 - val_categorical_accuracy: 0.3562
# Epoch 21/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.9738 - categorical_accuracy: 0.6839 - val_loss: 2.0062 - val_categorical_accuracy: 0.3625
# Epoch 22/100
# 10/10 [==============================] - 1s 97ms/step - loss: 1.0026 - categorical_accuracy: 0.6854 - val_loss: 1.9879 - val_categorical_accuracy: 0.3812
# Epoch 23/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.9605 - categorical_accuracy: 0.7042 - val_loss: 1.9574 - val_categorical_accuracy: 0.3812
# Epoch 24/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.9748 - categorical_accuracy: 0.6995 - val_loss: 1.9276 - val_categorical_accuracy: 0.3938
# Epoch 25/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.9029 - categorical_accuracy: 0.7308 - val_loss: 1.8973 - val_categorical_accuracy: 0.3938
# Epoch 26/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.8851 - categorical_accuracy: 0.7590 - val_loss: 1.8545 - val_categorical_accuracy: 0.4125
# Epoch 27/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.8492 - categorical_accuracy: 0.7512 - val_loss: 1.8190 - val_categorical_accuracy: 0.4125
# Epoch 28/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.8348 - categorical_accuracy: 0.7621 - val_loss: 1.7814 - val_categorical_accuracy: 0.4250
# Epoch 29/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.8046 - categorical_accuracy: 0.7934 - val_loss: 1.7182 - val_categorical_accuracy: 0.4500
# Epoch 30/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.8168 - categorical_accuracy: 0.7527 - val_loss: 1.6711 - val_categorical_accuracy: 0.4500
# Epoch 31/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.7712 - categorical_accuracy: 0.7778 - val_loss: 1.6432 - val_categorical_accuracy: 0.4437
# Epoch 32/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.7452 - categorical_accuracy: 0.7887 - val_loss: 1.6098 - val_categorical_accuracy: 0.4437
# Epoch 33/100
# 10/10 [==============================] - 1s 99ms/step - loss: 0.7094 - categorical_accuracy: 0.8106 - val_loss: 1.5810 - val_categorical_accuracy: 0.4688
# Epoch 34/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.6899 - categorical_accuracy: 0.8341 - val_loss: 1.5445 - val_categorical_accuracy: 0.4875
# Epoch 35/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.6788 - categorical_accuracy: 0.8341 - val_loss: 1.5056 - val_categorical_accuracy: 0.4875
# Epoch 36/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.6541 - categorical_accuracy: 0.8279 - val_loss: 1.4733 - val_categorical_accuracy: 0.5000
# Epoch 37/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.6268 - categorical_accuracy: 0.8545 - val_loss: 1.4430 - val_categorical_accuracy: 0.5000
# Epoch 38/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.5938 - categorical_accuracy: 0.8701 - val_loss: 1.4040 - val_categorical_accuracy: 0.5188
# Epoch 39/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.6092 - categorical_accuracy: 0.8670 - val_loss: 1.3630 - val_categorical_accuracy: 0.5375
# Epoch 40/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.6190 - categorical_accuracy: 0.8372 - val_loss: 1.3451 - val_categorical_accuracy: 0.5813
# Epoch 41/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.5740 - categorical_accuracy: 0.8623 - val_loss: 1.3695 - val_categorical_accuracy: 0.5500
# Epoch 42/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.5610 - categorical_accuracy: 0.8779 - val_loss: 1.3690 - val_categorical_accuracy: 0.5500
# Epoch 43/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.5688 - categorical_accuracy: 0.8920 - val_loss: 1.3107 - val_categorical_accuracy: 0.5875
# Epoch 44/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.5488 - categorical_accuracy: 0.8732 - val_loss: 1.2780 - val_categorical_accuracy: 0.6125
# Epoch 45/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.4983 - categorical_accuracy: 0.9045 - val_loss: 1.2575 - val_categorical_accuracy: 0.6375
# Epoch 46/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.5118 - categorical_accuracy: 0.8905 - val_loss: 1.2337 - val_categorical_accuracy: 0.6250
# Epoch 47/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.4985 - categorical_accuracy: 0.9030 - val_loss: 1.2142 - val_categorical_accuracy: 0.6625
# Epoch 48/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.4870 - categorical_accuracy: 0.9045 - val_loss: 1.1936 - val_categorical_accuracy: 0.6687
# Epoch 49/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.4572 - categorical_accuracy: 0.9108 - val_loss: 1.1718 - val_categorical_accuracy: 0.6562
# Epoch 50/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.4319 - categorical_accuracy: 0.9233 - val_loss: 1.1643 - val_categorical_accuracy: 0.6500
# Epoch 51/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.4252 - categorical_accuracy: 0.9264 - val_loss: 1.1819 - val_categorical_accuracy: 0.6313
# Epoch 52/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.4345 - categorical_accuracy: 0.9280 - val_loss: 1.1691 - val_categorical_accuracy: 0.6375
# Epoch 53/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.4319 - categorical_accuracy: 0.9139 - val_loss: 1.1630 - val_categorical_accuracy: 0.6438
# Epoch 54/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.3980 - categorical_accuracy: 0.9484 - val_loss: 1.1509 - val_categorical_accuracy: 0.6500
# Epoch 55/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.4142 - categorical_accuracy: 0.9390 - val_loss: 1.1124 - val_categorical_accuracy: 0.6812
# Epoch 56/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.4202 - categorical_accuracy: 0.9343 - val_loss: 1.0911 - val_categorical_accuracy: 0.6875
# Epoch 57/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.3962 - categorical_accuracy: 0.9358 - val_loss: 1.0712 - val_categorical_accuracy: 0.6875
# Epoch 58/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.3993 - categorical_accuracy: 0.9092 - val_loss: 1.0490 - val_categorical_accuracy: 0.6812
# Epoch 59/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.3926 - categorical_accuracy: 0.9437 - val_loss: 1.0255 - val_categorical_accuracy: 0.6938
# Epoch 60/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.3825 - categorical_accuracy: 0.9421 - val_loss: 1.0256 - val_categorical_accuracy: 0.7000
# Epoch 61/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.3831 - categorical_accuracy: 0.9405 - val_loss: 1.0196 - val_categorical_accuracy: 0.7125
# Epoch 62/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.3632 - categorical_accuracy: 0.9484 - val_loss: 1.0194 - val_categorical_accuracy: 0.7063
# Epoch 63/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.3640 - categorical_accuracy: 0.9437 - val_loss: 1.0163 - val_categorical_accuracy: 0.7188
# Epoch 64/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.3041 - categorical_accuracy: 0.9671 - val_loss: 0.9992 - val_categorical_accuracy: 0.7312
# Epoch 65/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.3358 - categorical_accuracy: 0.9609 - val_loss: 0.9904 - val_categorical_accuracy: 0.7375
# Epoch 66/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.3401 - categorical_accuracy: 0.9405 - val_loss: 0.9906 - val_categorical_accuracy: 0.7188
# Epoch 67/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.3235 - categorical_accuracy: 0.9687 - val_loss: 0.9735 - val_categorical_accuracy: 0.7125
# Epoch 68/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.3243 - categorical_accuracy: 0.9609 - val_loss: 0.9508 - val_categorical_accuracy: 0.7250
# Epoch 69/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.2945 - categorical_accuracy: 0.9656 - val_loss: 0.9396 - val_categorical_accuracy: 0.7125
# Epoch 70/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.3267 - categorical_accuracy: 0.9593 - val_loss: 0.9404 - val_categorical_accuracy: 0.7063
# Epoch 71/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.2997 - categorical_accuracy: 0.9624 - val_loss: 0.9446 - val_categorical_accuracy: 0.7125
# Epoch 72/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.3095 - categorical_accuracy: 0.9640 - val_loss: 0.9648 - val_categorical_accuracy: 0.7188
# Epoch 73/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.2679 - categorical_accuracy: 0.9687 - val_loss: 0.9619 - val_categorical_accuracy: 0.7312
# Epoch 74/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.2860 - categorical_accuracy: 0.9718 - val_loss: 0.9608 - val_categorical_accuracy: 0.7250
# Epoch 75/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.2870 - categorical_accuracy: 0.9687 - val_loss: 0.9314 - val_categorical_accuracy: 0.7312
# Epoch 76/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.2872 - categorical_accuracy: 0.9656 - val_loss: 0.9224 - val_categorical_accuracy: 0.7250
# Epoch 77/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.2735 - categorical_accuracy: 0.9687 - val_loss: 0.9401 - val_categorical_accuracy: 0.7250
# Epoch 78/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.2605 - categorical_accuracy: 0.9687 - val_loss: 0.9339 - val_categorical_accuracy: 0.7312
# Epoch 79/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.2781 - categorical_accuracy: 0.9687 - val_loss: 0.9165 - val_categorical_accuracy: 0.7563
# Epoch 80/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.2883 - categorical_accuracy: 0.9703 - val_loss: 0.9285 - val_categorical_accuracy: 0.7563
# Epoch 81/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.2436 - categorical_accuracy: 0.9781 - val_loss: 0.9402 - val_categorical_accuracy: 0.7375
# Epoch 82/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.2940 - categorical_accuracy: 0.9656 - val_loss: 0.9227 - val_categorical_accuracy: 0.7500
# Epoch 83/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.2537 - categorical_accuracy: 0.9781 - val_loss: 0.9163 - val_categorical_accuracy: 0.7375
# Epoch 84/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.2546 - categorical_accuracy: 0.9828 - val_loss: 0.9118 - val_categorical_accuracy: 0.7437
# Epoch 85/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.2235 - categorical_accuracy: 0.9844 - val_loss: 0.9120 - val_categorical_accuracy: 0.7312
# Epoch 86/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.2557 - categorical_accuracy: 0.9671 - val_loss: 0.9048 - val_categorical_accuracy: 0.7312
# Epoch 87/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.2557 - categorical_accuracy: 0.9703 - val_loss: 0.9062 - val_categorical_accuracy: 0.7375
# Epoch 88/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.2483 - categorical_accuracy: 0.9765 - val_loss: 0.9076 - val_categorical_accuracy: 0.7312
# Epoch 89/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.2348 - categorical_accuracy: 0.9703 - val_loss: 0.8997 - val_categorical_accuracy: 0.7437
# Epoch 90/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.2387 - categorical_accuracy: 0.9734 - val_loss: 0.8954 - val_categorical_accuracy: 0.7312
# Epoch 91/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.2443 - categorical_accuracy: 0.9687 - val_loss: 0.8939 - val_categorical_accuracy: 0.7500
# Epoch 92/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.2137 - categorical_accuracy: 0.9828 - val_loss: 0.8966 - val_categorical_accuracy: 0.7375
# Epoch 93/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.2298 - categorical_accuracy: 0.9797 - val_loss: 0.9017 - val_categorical_accuracy: 0.7312
# Epoch 94/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.2117 - categorical_accuracy: 0.9937 - val_loss: 0.8973 - val_categorical_accuracy: 0.7375
# Epoch 95/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.2162 - categorical_accuracy: 0.9812 - val_loss: 0.8758 - val_categorical_accuracy: 0.7312
# Epoch 96/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.2177 - categorical_accuracy: 0.9844 - val_loss: 0.8555 - val_categorical_accuracy: 0.7375
# Epoch 97/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.2134 - categorical_accuracy: 0.9812 - val_loss: 0.8614 - val_categorical_accuracy: 0.7563
# Epoch 98/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.2003 - categorical_accuracy: 0.9812 - val_loss: 0.8641 - val_categorical_accuracy: 0.7437
# Epoch 99/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.1900 - categorical_accuracy: 0.9828 - val_loss: 0.8682 - val_categorical_accuracy: 0.7250
# Epoch 100/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.1781 - categorical_accuracy: 0.9922 - val_loss: 0.8601 - val_categorical_accuracy: 0.7437

# %%
_, _, X_test, y_test, _, _, input_shape = load_classification_dataset(path_to_dataset, is_train_process=False)
evaluation = regular_classifier.evaluate(X_test, y_test)
predictions = regular_classifier.predict(X_test)
pickle.dump(predictions, open('test_classifications/regular_30_sec.pkl', 'wb'))
# Out:
# 7/7 [==============================] - 0s 13ms/step - loss: 0.9904 - categorical_accuracy: 0.6950
# 7/7 [==============================] - 0s 12ms/step

# %% [markdown]
# #3 Seconds Files

# %%
path_to_dataset ='../datasets/3_sec_datasets/classifier_dataset'
batch_size = 64
X_train, y_train, _, _, X_validation, y_validation, input_shape = load_classification_dataset(path_to_dataset, is_train_process=True)
train_indices = np.arange(X_train.shape[0])
np.random.shuffle(train_indices)
X_train_shuffled = X_train[train_indices]
y_train_shuffled = y_train[train_indices]

validation_indices = np.arange(X_validation.shape[0])
np.random.shuffle(validation_indices)
X_validation_shuffled = X_validation[validation_indices]
y_validation_shuffled = y_validation[validation_indices]

datasets = [X_train_shuffled, y_train_shuffled, X_validation_shuffled, y_validation_shuffled]

# %%
# path_to_dataset ='../datasets/3_sec_datasets'
# batch_size = 64
# train_gen, val_gen, test_gen = create_generators(path_to_dataset, batch_size)
# datasets = [train_gen, val_gen, test_gen]
# input_shape = (231, 232, 3)

# %% [markdown]
# ##Triplet Loss Based

# %%
model = create_conv_network(input_shape=input_shape, num_classes=10, branch_name='triplet_branch',
                            preload_weights=True, weights_path='../Siamese_Network/3_sec/triplet_branch.h5')
triplet_based_classifier = fit_and_save_model(datasets, batch_size, model, 'triplet', epochs=100, dtype='3_sec')
# Out:
# Epoch 1/100
# 100/100 [==============================] - 24s 176ms/step - loss: 2.2831 - categorical_accuracy: 0.2264 - val_loss: 2.1490 - val_categorical_accuracy: 0.2705
# Epoch 2/100
# 100/100 [==============================] - 8s 79ms/step - loss: 1.8773 - categorical_accuracy: 0.3434 - val_loss: 1.4227 - val_categorical_accuracy: 0.5285
# Epoch 3/100
# 100/100 [==============================] - 8s 79ms/step - loss: 1.6738 - categorical_accuracy: 0.4213 - val_loss: 1.3184 - val_categorical_accuracy: 0.5855
# Epoch 4/100
# 100/100 [==============================] - 8s 79ms/step - loss: 1.4770 - categorical_accuracy: 0.4940 - val_loss: 1.2473 - val_categorical_accuracy: 0.6137
# Epoch 5/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.3485 - categorical_accuracy: 0.5369 - val_loss: 1.2382 - val_categorical_accuracy: 0.6055
# Epoch 6/100
# 100/100 [==============================] - 8s 79ms/step - loss: 1.1965 - categorical_accuracy: 0.6092 - val_loss: 1.1380 - val_categorical_accuracy: 0.6456
# Epoch 7/100
# 100/100 [==============================] - 8s 79ms/step - loss: 1.0578 - categorical_accuracy: 0.6519 - val_loss: 1.0633 - val_categorical_accuracy: 0.6713
# Epoch 8/100
# 100/100 [==============================] - 8s 80ms/step - loss: 0.9610 - categorical_accuracy: 0.7024 - val_loss: 0.9004 - val_categorical_accuracy: 0.7401
# Epoch 9/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.8465 - categorical_accuracy: 0.7407 - val_loss: 0.9095 - val_categorical_accuracy: 0.7345
# Epoch 10/100
# 100/100 [==============================] - 8s 80ms/step - loss: 0.7382 - categorical_accuracy: 0.7907 - val_loss: 0.8799 - val_categorical_accuracy: 0.7414
# Epoch 11/100
# 100/100 [==============================] - 8s 79ms/step - loss: 0.6567 - categorical_accuracy: 0.8271 - val_loss: 0.8513 - val_categorical_accuracy: 0.7439
# Epoch 12/100
# 100/100 [==============================] - 8s 79ms/step - loss: 0.5681 - categorical_accuracy: 0.8566 - val_loss: 0.8045 - val_categorical_accuracy: 0.7502
# Epoch 13/100
# 100/100 [==============================] - 8s 79ms/step - loss: 0.5170 - categorical_accuracy: 0.8801 - val_loss: 0.7164 - val_categorical_accuracy: 0.7984
# Epoch 14/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.4503 - categorical_accuracy: 0.9043 - val_loss: 0.7402 - val_categorical_accuracy: 0.7890
# Epoch 15/100
# 100/100 [==============================] - 8s 80ms/step - loss: 0.4003 - categorical_accuracy: 0.9180 - val_loss: 0.6812 - val_categorical_accuracy: 0.8034
# Epoch 16/100
# 100/100 [==============================] - 8s 79ms/step - loss: 0.3390 - categorical_accuracy: 0.9389 - val_loss: 0.6634 - val_categorical_accuracy: 0.8084
# Epoch 17/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.3177 - categorical_accuracy: 0.9455 - val_loss: 0.6677 - val_categorical_accuracy: 0.8009
# Epoch 18/100
# 100/100 [==============================] - 8s 79ms/step - loss: 0.2797 - categorical_accuracy: 0.9527 - val_loss: 0.6409 - val_categorical_accuracy: 0.8078
# Epoch 19/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.2401 - categorical_accuracy: 0.9688 - val_loss: 0.6514 - val_categorical_accuracy: 0.8015
# Epoch 20/100
# 100/100 [==============================] - 8s 79ms/step - loss: 0.2164 - categorical_accuracy: 0.9723 - val_loss: 0.6101 - val_categorical_accuracy: 0.8159
# Epoch 21/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.2104 - categorical_accuracy: 0.9717 - val_loss: 0.6286 - val_categorical_accuracy: 0.8159
# Epoch 22/100
# 100/100 [==============================] - 8s 80ms/step - loss: 0.1792 - categorical_accuracy: 0.9789 - val_loss: 0.5661 - val_categorical_accuracy: 0.8253
# Epoch 23/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.1593 - categorical_accuracy: 0.9828 - val_loss: 0.6258 - val_categorical_accuracy: 0.8021
# Epoch 24/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.1503 - categorical_accuracy: 0.9839 - val_loss: 0.6107 - val_categorical_accuracy: 0.8009
# Epoch 25/100
# 100/100 [==============================] - 8s 79ms/step - loss: 0.1431 - categorical_accuracy: 0.9868 - val_loss: 0.5593 - val_categorical_accuracy: 0.8234
# Epoch 26/100
# 100/100 [==============================] - 8s 80ms/step - loss: 0.1283 - categorical_accuracy: 0.9879 - val_loss: 0.5522 - val_categorical_accuracy: 0.8291
# Epoch 27/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.1214 - categorical_accuracy: 0.9881 - val_loss: 0.5583 - val_categorical_accuracy: 0.8309
# Epoch 28/100
# 100/100 [==============================] - 8s 79ms/step - loss: 0.1104 - categorical_accuracy: 0.9906 - val_loss: 0.5487 - val_categorical_accuracy: 0.8328
# Epoch 29/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.1067 - categorical_accuracy: 0.9914 - val_loss: 0.5605 - val_categorical_accuracy: 0.8309
# Epoch 30/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.0987 - categorical_accuracy: 0.9906 - val_loss: 0.5648 - val_categorical_accuracy: 0.8228
# Epoch 31/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.0932 - categorical_accuracy: 0.9920 - val_loss: 0.5634 - val_categorical_accuracy: 0.8259
# Epoch 32/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.0840 - categorical_accuracy: 0.9944 - val_loss: 0.5639 - val_categorical_accuracy: 0.8247
# Epoch 33/100
# 100/100 [==============================] - 8s 79ms/step - loss: 0.0765 - categorical_accuracy: 0.9950 - val_loss: 0.5424 - val_categorical_accuracy: 0.8410
# Epoch 34/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.0728 - categorical_accuracy: 0.9947 - val_loss: 0.5703 - val_categorical_accuracy: 0.8322
# Epoch 35/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.0691 - categorical_accuracy: 0.9948 - val_loss: 0.5754 - val_categorical_accuracy: 0.8297
# Epoch 36/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.0640 - categorical_accuracy: 0.9972 - val_loss: 0.5617 - val_categorical_accuracy: 0.8303
# Epoch 37/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.0602 - categorical_accuracy: 0.9973 - val_loss: 0.6135 - val_categorical_accuracy: 0.8109
# Epoch 38/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.0552 - categorical_accuracy: 0.9972 - val_loss: 0.5605 - val_categorical_accuracy: 0.8341
# Epoch 39/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.0557 - categorical_accuracy: 0.9961 - val_loss: 0.6725 - val_categorical_accuracy: 0.8109
# Epoch 40/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0554 - categorical_accuracy: 0.9961Restoring model weights from the end of the best epoch: 33.
# 100/100 [==============================] - 8s 80ms/step - loss: 0.0554 - categorical_accuracy: 0.9961 - val_loss: 0.5685 - val_categorical_accuracy: 0.8209
# Epoch 40: early stopping

# %%
_, _, X_test, y_test, _, _, input_shape = load_classification_dataset(path_to_dataset, is_train_process=False)
evaluation = triplet_based_classifier.evaluate(X_test, y_test)
predictions = triplet_based_classifier.predict(X_test)
pickle.dump(predictions, open('test_classifications/triplet_3_sec.pkl', 'wb'))
# Out:
# 63/63 [==============================] - 3s 22ms/step - loss: 0.5239 - categorical_accuracy: 0.8393
# 63/63 [==============================] - 1s 13ms/step

# %% [markdown]
# ##Contrastive Loss Based

# %%
model = create_conv_network(input_shape=input_shape, num_classes=10, branch_name='contrast_branch',
                            preload_weights=True, weights_path='../Siamese_Network/3_sec/contrast_branch.h5')
contrast_based_classifier = fit_and_save_model(datasets, batch_size, model, 'contrast', epochs=100, dtype='3_sec')
# Out:
# Epoch 1/100
# 100/100 [==============================] - 11s 101ms/step - loss: 2.5020 - categorical_accuracy: 0.1827 - val_loss: 1.9030 - val_categorical_accuracy: 0.2730
# Epoch 2/100
# 100/100 [==============================] - 8s 79ms/step - loss: 2.1206 - categorical_accuracy: 0.2806 - val_loss: 1.6575 - val_categorical_accuracy: 0.4433
# Epoch 3/100
# 100/100 [==============================] - 8s 79ms/step - loss: 1.8835 - categorical_accuracy: 0.3506 - val_loss: 1.6254 - val_categorical_accuracy: 0.4577
# Epoch 4/100
# 100/100 [==============================] - 8s 79ms/step - loss: 1.6656 - categorical_accuracy: 0.4299 - val_loss: 1.5023 - val_categorical_accuracy: 0.5110
# Epoch 5/100
# 100/100 [==============================] - 8s 79ms/step - loss: 1.4960 - categorical_accuracy: 0.4782 - val_loss: 1.3515 - val_categorical_accuracy: 0.5736
# Epoch 6/100
# 100/100 [==============================] - 8s 79ms/step - loss: 1.3419 - categorical_accuracy: 0.5450 - val_loss: 1.1356 - val_categorical_accuracy: 0.6462
# Epoch 7/100
# 100/100 [==============================] - 8s 79ms/step - loss: 1.2209 - categorical_accuracy: 0.5915 - val_loss: 1.0317 - val_categorical_accuracy: 0.6913
# Epoch 8/100
# 100/100 [==============================] - 8s 79ms/step - loss: 1.0969 - categorical_accuracy: 0.6441 - val_loss: 1.0201 - val_categorical_accuracy: 0.7026
# Epoch 9/100
# 100/100 [==============================] - 8s 79ms/step - loss: 0.9772 - categorical_accuracy: 0.6939 - val_loss: 0.9972 - val_categorical_accuracy: 0.6894
# Epoch 10/100
# 100/100 [==============================] - 8s 79ms/step - loss: 0.8822 - categorical_accuracy: 0.7351 - val_loss: 0.8844 - val_categorical_accuracy: 0.7401
# Epoch 11/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.7850 - categorical_accuracy: 0.7747 - val_loss: 0.8860 - val_categorical_accuracy: 0.7389
# Epoch 12/100
# 100/100 [==============================] - 8s 79ms/step - loss: 0.6873 - categorical_accuracy: 0.8116 - val_loss: 0.7716 - val_categorical_accuracy: 0.7808
# Epoch 13/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.6033 - categorical_accuracy: 0.8506 - val_loss: 0.8461 - val_categorical_accuracy: 0.7345
# Epoch 14/100
# 100/100 [==============================] - 8s 79ms/step - loss: 0.5358 - categorical_accuracy: 0.8791 - val_loss: 0.7669 - val_categorical_accuracy: 0.7852
# Epoch 15/100
# 100/100 [==============================] - 8s 79ms/step - loss: 0.4784 - categorical_accuracy: 0.8913 - val_loss: 0.6724 - val_categorical_accuracy: 0.8084
# Epoch 16/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.4288 - categorical_accuracy: 0.9117 - val_loss: 0.7705 - val_categorical_accuracy: 0.7702
# Epoch 17/100
# 100/100 [==============================] - 8s 79ms/step - loss: 0.3724 - categorical_accuracy: 0.9280 - val_loss: 0.6314 - val_categorical_accuracy: 0.8147
# Epoch 18/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.3377 - categorical_accuracy: 0.9405 - val_loss: 0.6518 - val_categorical_accuracy: 0.7996
# Epoch 19/100
# 100/100 [==============================] - 8s 79ms/step - loss: 0.2967 - categorical_accuracy: 0.9463 - val_loss: 0.6202 - val_categorical_accuracy: 0.8228
# Epoch 20/100
# 100/100 [==============================] - 8s 79ms/step - loss: 0.2676 - categorical_accuracy: 0.9558 - val_loss: 0.6061 - val_categorical_accuracy: 0.8197
# Epoch 21/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.2408 - categorical_accuracy: 0.9648 - val_loss: 0.6349 - val_categorical_accuracy: 0.8109
# Epoch 22/100
# 100/100 [==============================] - 8s 79ms/step - loss: 0.2179 - categorical_accuracy: 0.9720 - val_loss: 0.6018 - val_categorical_accuracy: 0.8234
# Epoch 23/100
# 100/100 [==============================] - 8s 79ms/step - loss: 0.1889 - categorical_accuracy: 0.9776 - val_loss: 0.6437 - val_categorical_accuracy: 0.8034
# Epoch 24/100
# 100/100 [==============================] - 8s 79ms/step - loss: 0.1759 - categorical_accuracy: 0.9829 - val_loss: 0.5967 - val_categorical_accuracy: 0.8172
# Epoch 25/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.1634 - categorical_accuracy: 0.9825 - val_loss: 0.6451 - val_categorical_accuracy: 0.7902
# Epoch 26/100
# 100/100 [==============================] - 8s 79ms/step - loss: 0.1574 - categorical_accuracy: 0.9828 - val_loss: 0.5802 - val_categorical_accuracy: 0.8178
# Epoch 27/100
# 100/100 [==============================] - 8s 80ms/step - loss: 0.1376 - categorical_accuracy: 0.9872 - val_loss: 0.5712 - val_categorical_accuracy: 0.8240
# Epoch 28/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.1268 - categorical_accuracy: 0.9876 - val_loss: 0.5899 - val_categorical_accuracy: 0.8197
# Epoch 29/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.1179 - categorical_accuracy: 0.9892 - val_loss: 0.5780 - val_categorical_accuracy: 0.8203
# Epoch 30/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.1113 - categorical_accuracy: 0.9895 - val_loss: 0.6261 - val_categorical_accuracy: 0.8096
# Epoch 31/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.1059 - categorical_accuracy: 0.9925 - val_loss: 0.5726 - val_categorical_accuracy: 0.8240
# Epoch 32/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.1004 - categorical_accuracy: 0.9909 - val_loss: 0.5832 - val_categorical_accuracy: 0.8121
# Epoch 33/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.0915 - categorical_accuracy: 0.9925 - val_loss: 0.5719 - val_categorical_accuracy: 0.8272
# Epoch 34/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0817 - categorical_accuracy: 0.9950Restoring model weights from the end of the best epoch: 27.
# 100/100 [==============================] - 8s 80ms/step - loss: 0.0817 - categorical_accuracy: 0.9950 - val_loss: 0.5891 - val_categorical_accuracy: 0.8147
# Epoch 34: early stopping

# %%
_, _, X_test, y_test, _, _, input_shape = load_classification_dataset(path_to_dataset, is_train_process=False)
evaluation = contrast_based_classifier.evaluate(X_test, y_test)
predictions = contrast_based_classifier.predict(X_test)
pickle.dump(predictions, open('test_classifications/contrastive_3_sec.pkl', 'wb'))
# Out:
# 63/63 [==============================] - 1s 14ms/step - loss: 0.5644 - categorical_accuracy: 0.8312
# 63/63 [==============================] - 1s 13ms/step

# %% [markdown]
# ##Regular Loss - No Transfer Learning

# %%
model = create_conv_network(input_shape=input_shape, num_classes=10,
                            branch_name='regular_branch', preload_weights=False)
regular_classifier = fit_and_save_model(datasets, batch_size, model, 'regular', epochs=100, dtype='3_sec')
# Out:
# Epoch 1/100
# 100/100 [==============================] - 12s 103ms/step - loss: 2.3385 - categorical_accuracy: 0.2172 - val_loss: 2.3099 - val_categorical_accuracy: 0.1465
# Epoch 2/100
# 100/100 [==============================] - 8s 78ms/step - loss: 1.8852 - categorical_accuracy: 0.3404 - val_loss: 2.3109 - val_categorical_accuracy: 0.1747
# Epoch 3/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.6129 - categorical_accuracy: 0.4371 - val_loss: 2.1095 - val_categorical_accuracy: 0.2912
# Epoch 4/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.4299 - categorical_accuracy: 0.5057 - val_loss: 1.6150 - val_categorical_accuracy: 0.4408
# Epoch 5/100
# 100/100 [==============================] - 8s 79ms/step - loss: 1.3000 - categorical_accuracy: 0.5685 - val_loss: 1.3769 - val_categorical_accuracy: 0.5266
# Epoch 6/100
# 100/100 [==============================] - 8s 80ms/step - loss: 1.1420 - categorical_accuracy: 0.6205 - val_loss: 1.0817 - val_categorical_accuracy: 0.6594
# Epoch 7/100
# 100/100 [==============================] - 8s 79ms/step - loss: 0.9966 - categorical_accuracy: 0.6848 - val_loss: 0.9418 - val_categorical_accuracy: 0.7301
# Epoch 8/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.8974 - categorical_accuracy: 0.7249 - val_loss: 0.9542 - val_categorical_accuracy: 0.7032
# Epoch 9/100
# 100/100 [==============================] - 8s 79ms/step - loss: 0.7819 - categorical_accuracy: 0.7719 - val_loss: 0.7900 - val_categorical_accuracy: 0.7802
# Epoch 10/100
# 100/100 [==============================] - 8s 80ms/step - loss: 0.6896 - categorical_accuracy: 0.8106 - val_loss: 0.7647 - val_categorical_accuracy: 0.7840
# Epoch 11/100
# 100/100 [==============================] - 8s 80ms/step - loss: 0.5997 - categorical_accuracy: 0.8486 - val_loss: 0.6979 - val_categorical_accuracy: 0.8003
# Epoch 12/100
# 100/100 [==============================] - 8s 79ms/step - loss: 0.5405 - categorical_accuracy: 0.8685 - val_loss: 0.6663 - val_categorical_accuracy: 0.8059
# Epoch 13/100
# 100/100 [==============================] - 8s 79ms/step - loss: 0.4791 - categorical_accuracy: 0.8929 - val_loss: 0.6552 - val_categorical_accuracy: 0.8134
# Epoch 14/100
# 100/100 [==============================] - 8s 79ms/step - loss: 0.4188 - categorical_accuracy: 0.9126 - val_loss: 0.6484 - val_categorical_accuracy: 0.8121
# Epoch 15/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.3685 - categorical_accuracy: 0.9294 - val_loss: 0.6532 - val_categorical_accuracy: 0.8153
# Epoch 16/100
# 100/100 [==============================] - 8s 79ms/step - loss: 0.3340 - categorical_accuracy: 0.9385 - val_loss: 0.5992 - val_categorical_accuracy: 0.8140
# Epoch 17/100
# 100/100 [==============================] - 8s 79ms/step - loss: 0.2885 - categorical_accuracy: 0.9518 - val_loss: 0.6708 - val_categorical_accuracy: 0.7927
# Epoch 18/100
# 100/100 [==============================] - 8s 80ms/step - loss: 0.2640 - categorical_accuracy: 0.9599 - val_loss: 0.5717 - val_categorical_accuracy: 0.8322
# Epoch 19/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.2315 - categorical_accuracy: 0.9720 - val_loss: 0.5765 - val_categorical_accuracy: 0.8384
# Epoch 20/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.2127 - categorical_accuracy: 0.9713 - val_loss: 0.5794 - val_categorical_accuracy: 0.8284
# Epoch 21/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.1939 - categorical_accuracy: 0.9732 - val_loss: 0.5806 - val_categorical_accuracy: 0.8228
# Epoch 22/100
# 100/100 [==============================] - 8s 80ms/step - loss: 0.1761 - categorical_accuracy: 0.9806 - val_loss: 0.5613 - val_categorical_accuracy: 0.8309
# Epoch 23/100
# 100/100 [==============================] - 8s 79ms/step - loss: 0.1608 - categorical_accuracy: 0.9809 - val_loss: 0.5510 - val_categorical_accuracy: 0.8278
# Epoch 24/100
# 100/100 [==============================] - 8s 79ms/step - loss: 0.1486 - categorical_accuracy: 0.9859 - val_loss: 0.6104 - val_categorical_accuracy: 0.8134
# Epoch 25/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.1309 - categorical_accuracy: 0.9864 - val_loss: 0.5962 - val_categorical_accuracy: 0.8115
# Epoch 26/100
# 100/100 [==============================] - 8s 80ms/step - loss: 0.1244 - categorical_accuracy: 0.9887 - val_loss: 0.5471 - val_categorical_accuracy: 0.8322
# Epoch 27/100
# 100/100 [==============================] - 8s 79ms/step - loss: 0.1236 - categorical_accuracy: 0.9862 - val_loss: 0.5301 - val_categorical_accuracy: 0.8322
# Epoch 28/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.1057 - categorical_accuracy: 0.9915 - val_loss: 0.5787 - val_categorical_accuracy: 0.8203
# Epoch 29/100
# 100/100 [==============================] - 8s 79ms/step - loss: 0.0979 - categorical_accuracy: 0.9928 - val_loss: 0.5430 - val_categorical_accuracy: 0.8309
# Epoch 30/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.0906 - categorical_accuracy: 0.9928 - val_loss: 0.5749 - val_categorical_accuracy: 0.8178
# Epoch 31/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.0905 - categorical_accuracy: 0.9933 - val_loss: 0.5358 - val_categorical_accuracy: 0.8359
# Epoch 32/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.0795 - categorical_accuracy: 0.9945 - val_loss: 0.5335 - val_categorical_accuracy: 0.8359
# Epoch 33/100
# 100/100 [==============================] - 8s 78ms/step - loss: 0.0775 - categorical_accuracy: 0.9936 - val_loss: 0.5525 - val_categorical_accuracy: 0.8272
# Epoch 34/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0720 - categorical_accuracy: 0.9942Restoring model weights from the end of the best epoch: 27.
# 100/100 [==============================] - 8s 80ms/step - loss: 0.0720 - categorical_accuracy: 0.9942 - val_loss: 0.5633 - val_categorical_accuracy: 0.8278
# Epoch 34: early stopping

# %%
_, _, X_test, y_test, _, _, input_shape = load_classification_dataset(path_to_dataset, is_train_process=False)
evaluation = regular_classifier.evaluate(X_test, y_test)
predictions = regular_classifier.predict(X_test)
pickle.dump(predictions, open('test_classifications/regular_3_sec.pkl', 'wb'))
# Out:
# 63/63 [==============================] - 1s 14ms/step - loss: 0.5233 - categorical_accuracy: 0.8373
# 63/63 [==============================] - 1s 13ms/step
